# %% [markdown]
# # 유튜브에서 크롤링한 댓글 전처리 진행하기

# %% [markdown]
# ## Import library

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from konlpy.tag import Okt

# %% [markdown]
# ## 데이터 전처리 시작
#
# ### 데이터 불러오기
# usecols을 이용해서 필요한 comment 부분만 가져왔다

# %%
data = pd.read_excel('1_말안듣는말.xlsx', usecols = ['comment'])
data
# Out:
#                                                 comment
# 0     로봇말로 바꾸던지;; 말을 바꿔서 시도를 여러번 할수있게 해주던지;; 오늘 처음만난...
# 1                         같은 말로 해야 형편성에 맞지 않냐? 이건 좀 아닌듯
# 2                                            말 죽이고 싶었겠다
# 3                                 말이 경기를 뛰는데 사람이 평가받는구만
# 4                                         당근 챙겨가면 안되나??
# ...                                                 ...
# 7119                                 @현호 ㄹㅇ 다시보니 ㅁ친놈임ㅋㅋ
# 7120                                               ㅋㅋㅋㅋ
# 7121  김유신 이야기는 ㅈㄴ 웃긴게 자기가 인사불성인상태에서 주인이 자주가는곳 잘 데리다줫...
# 7122                                                헐..
# 7123                                               말고기행
#
# [7124 rows x 1 columns]

# %% [markdown]
# ### 데이터 중복확인
# 데이터 중복있는지 확인하기 위해서 고유값만 출력하는 nunique() 사용

# %%
data['comment'].nunique()
# Out:
# 6966

# %% [markdown]
# ### 중복 제거

# %%
data.drop_duplicates(subset = ['comment'], inplace=True) # 중복 제거
data = data.dropna(how = 'any') # Null 값이 존재하는 행 제거

# %%
len(data) # 잘 제거되었는지 확인
# Out:
# 6966

# %% [markdown]
# ### 정규 표현식을 이용하여 한글, 공백을 제외하고 제거하기

# %%
data['comment'] = data['comment'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")

# 잘 되었구나
data[:10]
# Out:
# <ipython-input-54-aedb2aa454cb>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['comment'] = data['comment'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
#                                              comment
# 0  로봇말로 바꾸던지 말을 바꿔서 시도를 여러번 할수있게 해주던지 오늘 처음만난 말새끠...
# 1                       같은 말로 해야 형편성에 맞지 않냐 이건 좀 아닌듯
# 2                                         말 죽이고 싶었겠다
# 3                              말이 경기를 뛰는데 사람이 평가받는구만
# 4                                        당근 챙겨가면 안되나
# 5                                         전라도 말인가 보네
# 6                             말이 하기 싫다는데 하는것도 말이 안되죠
# 7                                방구석 여포들 적토마 타는 소리하네
# 8      랜덤으로 하면 비리도 있을 것 같은 느낌 정말 단점들 투성이인데도 랜덤으로 하네요
# 9                  운이 경기 성적에 많이 반영되면 로또도 올림픽에 넣지 그러냐

# %% [markdown]
# ### 빈값 다시 확인
# 정규표현식을 이용해서 제거하게되면, 빈 값이 생길게 뻔히 보여서 빈값 확인 및 null값으로 만들어서 제거합니당

# %%
data['comment'].replace('', np.nan, inplace=True) # null값으로 만들어주기
print(data.isnull().sum()) # 총 몇 개인지 확인
# Out:
# comment    5
# dtype: int64

# %%
# null 값을 가진 샘플 확인
data.loc[data.comment.isnull()]
# Out:
#      comment
# 255      NaN
# 303      NaN
# 3591     NaN
# 5151     NaN
# 5219     NaN

# %%
# null값아 잘가라~
data = data.dropna(how = 'any')

# %% [markdown]
# ### 불용어 제거 및 토큰화

# %%
# 불용어 단계에서 "신조어"를 위주로 추출하려면 불용어 리스트를 더 추가하는 것이 좋을 듯 싶다 
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
# 불용어제거하면서 토큰화 okt 이용
okt = Okt()

res = []
for sentence in data['comment']:
    lis = []
    lis = okt.morphs(sentence, stem=True) # 토큰화
    lis = [word for word in lis if not word in stopwords] # 불용어 제거
    res.append(lis)

# %%
res
# Out:
# [['로봇',
#   '말로',
#   '바꾸다',
#   '말',
#   '을',
#   '바꾸다',
#   '시도',
#   '여러',
#   '번',
#   '해주다',
#   '오늘',
#   '처음',
#   '만',
#   '난',
#   '말새끠',
#   '말',
#   '을',
#   '안',
#   '듣다',
#   '어쩌라고',
#   'ㅠㅠ',
#   '너무',
#   '억울하다',
#   '안타깝다',
#   'ㅠㅠ'],
#  ['같다', '말로', '형편', '성', '맞다', '않다', '이건', '아니다'],
#  ['말', '죽', '이고', '싶다'],
#  ['말', '경기', '뛰다', '사람', '평가', '받다'],
#  ['당근', '챙기다', '안되다'],
#  ['전라도', '말', '인가', '보다'],
#  ['말', '싫다', '말', '안되다'],
#  ['방', '구석', '여포', '적토마', '타다', '소리'],
#  ['랜덤', '비리', '있다', '것', '같다', '느낌', '정말', '단점', '투성이', '인데', '랜덤'],
#  ['운', '경기', '성적', '많이', '반영', '되다', '로또', '올림픽', '넣다', '그렇다'],
#  ['말', '말', '을', '끼다', '놓다', '순위', '뒤죽박죽', '되다'],
#  ['나다', '경기', '끝나다', '저', '말', '목', '찌르다', '죽이다'],
#  ['근대',
#   '종목',
#   '비',
#   '인기',
#   '인',
#   '이유',
#   '알다',
#   '스포츠',
#   '무작위',
#   '배정',
#   '말',
#   '이라는',
#   '운빨',
#   '요소',
#   '들어가다',
#   '말',
#   '선택',
#   '해주다',
#   '사람',
#   '만',
#   '메달',
#   '권',
#   '가능하다'],
#  ['적어도', '하루', '정도', '충분하다', '시간', '을', '주다', '어떻다'],
#  ['말', '대신', '오토바이', '로', '바꾸다'],
#  ['말타', '기다', '빼다', '차라리', '카레이싱', '을', '넣다'],
#  ['말', 'ㅈㄴ', '불쌍하다'],
#  ['저', '선수', '빡치다', '돌아가다', '말고기', '겁나다', '먹다', 'ㅠ'],
#  ['평화',
#   '상징',
#   '인',
#   '올림픽',
#   '에서',
#   '전쟁',
#   '에서',
#   '적의',
#   '말',
#   '을',
#   '뺏다',
#   '타고',
#   '간다',
#   '설정',
#   '자체',
#   '말',
#   '안',
#   '되다',
#   '경기'],
#  ['아', '하늘이시여'],
#  ['말', '뽑다'],
#  ['요즘',
#   '삼성',
#   '같다',
#   '대기업',
#   '선수',
#   '한테',
#   '말',
#   '지원',
#   '알다',
#   '남아',
#   '못',
#   '하',
#   '지',
#   '잘못',
#   '좌빨',
#   '한테',
#   '죽다'],
#  ['이건',
#   '뭐',
#   '말',
#   '선택',
#   '로또',
#   '잖다',
#   '다',
#   '어느',
#   '정도',
#   '말',
#   '품성',
#   '이나',
#   '능력',
#   '기준',
#   '치가',
#   '넘다',
#   '다해',
#   '운',
#   '엄청',
#   '작용',
#   '한다는',
#   '건',
#   '사실',
#   '이런',
#   '걸',
#   '철저하다',
#   '피땀',
#   '흘리다',
#   '노력',
#   '하고',
#   '준비',
#   '실력',
#   '이라',
#   '건가'],
#  ['말', '을', '추첨', '한다는', '것', '스포츠', '로써', '맞다', '않다', '같다'],
#  ['말', '보단', '사이클', '로', '가다'],
#  ['게', '뭔', '스포츠', '냐'],
#  ['저', '룰', '말', '스트레스', '받다', '않다'],
#  ['글쎄요',
#   '아무리',
#   '인간',
#   '위주',
#   '로',
#   '보다',
#   '해도',
#   '다',
#   '크다',
#   '성인',
#   '저렇게',
#   '자기',
#   '제어',
#   '못',
#   '소리',
#   '날',
#   '정도',
#   '로',
#   '울다',
#   '것',
#   '꼭',
#   '동정',
#   '만',
#   '받다',
#   '일',
#   '아니다',
#   '울다',
#   '전',
#   '말',
#   '을',
#   '구타',
#   '하고',
#   '코치',
#   '말',
#   '때리다',
#   '징계',
#   '까지',
#   '먹다',
#   '블랙',
#   '카드',
#   '까지',
#   '받다',
#   '말',
#   '무슨',
#   '죄',
#   '인가요',
#   '선수',
#   '말',
#   '선택',
#   '불운',
#   '것',
#   '아니다',
#   '말',
#   '기량',
#   '안되다',
#   '선수',
#   '코치',
#   '만난',
#   '겁니다',
#   '이름',
#   '처럼',
#   '성자',
#   '같다',
#   '말',
#   '이라서',
#   '참다',
#   '겁니다',
#   '만약',
#   '시합',
#   '전',
#   '문제',
#   '일으키다',
#   '당연하다',
#   '저',
#   '말',
#   '제외',
#   '되다',
#   '아무',
#   '문제',
#   '없다',
#   '못',
#   '난',
#   '기수',
#   '만나다',
#   '매',
#   '맞다',
#   '고통',
#   '받다',
#   '겁니다',
#   '애도',
#   '아니다',
#   '고누',
#   '죽다',
#   '왜',
#   '대성통곡',
#   '을',
#   '말',
#   '채찍',
#   '질',
#   '모습',
#   '인성',
#   '나',
#   '보임',
#   '저',
#   '질'],
#  ['어뜩하다', 'ㅜㅜㅜ', '얼마나', '속상하다', 'ㅜㅜ', '너무', '슬프다', 'ㅜㅜㅜㅜ'],
#  ['말',
#   '스트레스',
#   '많이',
#   '받다',
#   '같다',
#   'ㅠㅠ',
#   '말',
#   '지정',
#   '해주다',
#   '전',
#   '컨디션',
#   '한번',
#   '더',
#   '자다',
#   '살피다',
#   '괜찮다',
#   '말',
#   '만',
#   '고르다',
#   '야하다'],
#  ['불쌍하다', 'ㅠ'],
#  ['저', '말색', '희다', '끝나다', '회', '뜨다', '먹다', 'ㅋㅋㅋㅋㅋ'],
#  ['말', '말', '인데', '크다', '사다'],
#  ['코치', '한테', '폭행', '당', '하고', '말', '빡치다'],
#  ['ㅈㅓ', '런', '미츤냔', '말', '학대'],
#  ['경기장', '진짜', '조잡하다'],
#  ['거', '무슨', '적의', '차', '빼다', '차키', '없다', '꼴', '이자나', 'ㅅㅂ'],
#  ['경기장', '장애물', '색', '너무', '튀다', '그래서', '말', '적응', '을', '못', '하고', '놀라다'],
#  ['다루다', '모르다', '울면', '달다'],
#  ['올림픽', '인간', '육체', '도구', '만', '갖다', '경기', '맞다'],
#  ['문제', '있다', '폐지', '한데', '딱하다', '문제', '이번', '만', '있다', '가요'],
#  ['말',
#   '차다',
#   '불쌍하다',
#   '수십',
#   '키',
#   '로',
#   '등',
#   '달',
#   '고',
#   '점프',
#   '승마',
#   '사라지다',
#   '스포츠',
#   '라고',
#   '생각',
#   '함'],
#  ['우리', '에게', '교훈', '을', '주시', '거', '죠', '맞다'],
#  ['저런', '룰', '면', '승부조작', '충분하다', '가능하다'],
#  ['저건',
#   '선수',
#   '한테',
#   '잔인하다',
#   '말',
#   '한테',
#   '동물학대',
#   '다',
#   '만난',
#   '지',
#   '얼마',
#   '안되다',
#   '사람',
#   '이랑',
#   '교감',
#   '하',
#   '라니',
#   'ㅉ'],
#  ['아', 'ㅅㅂ', '마지막', '이승엽', '보고', '핸드폰', '던지다', '뻔', '채널', '다시다', '볼일', '없다'],
#  ['김유신', '인정'],
#  ['아', '너무', '속상하다', 'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['말', '복불복', '이네'],
#  ['아', '너무', '속상하다', '진짜', '안타깝다'],
#  ['이제', '바뀌다', '필요', '있다', '않다'],
#  ['저러다', '선수', '크게', '다치다', '않다', '걱정', '되다'],
#  ['저', '말', '다시다', '경기장', '발', '못', '들이다', '되다', '진짜'],
#  ['표정', '보다', '말', '새끼', 'ㅋㅋㅋㅋ', '존나', '얄밉다'],
#  ['말', '어디', '아프다', '아니다', '쟤', '얼마나', '싫다', '저러다'],
#  ['김유신', '빙의', '싶다'],
#  ['울다', '모', '습보', '니', '안타깝다', '기도', 'ㅜㅜㅜㅜ'],
#  ['안락사', '되다', '임'],
#  ['뭔', '소리', '얔', 'ㅋㅋ'],
#  ['그냥', '가위바위보', '뭐', '다르다'],
#  ['ㅠㅠㅠ',
#   '승마',
#   '자다',
#   '알',
#   '지는',
#   '못',
#   '그래도',
#   '나름',
#   '대로',
#   '열심히',
#   '준비',
#   '경기',
#   'ㅠㅠ'],
#  ['복불복', '참다', '웃기다'],
#  ['올림픽',
#   '을',
#   '세계',
#   '인',
#   '축제',
#   '라고',
#   '말',
#   '을',
#   '하지만',
#   '선수',
#   '에게는',
#   '과연',
#   '축제',
#   '이다',
#   '요',
#   '그야말로',
#   '전쟁',
#   '터',
#   '죠',
#   '싸우다',
#   '이기다',
#   '끝',
#   '까지',
#   '살아나다',
#   '선수',
#   '개개인',
#   '인생',
#   '달리다',
#   '겁니다',
#   '한번',
#   '간단하다',
#   '추첨',
#   '치열하다',
#   '살아오다',
#   '인생',
#   '짓밟힌다',
#   '게',
#   '진정하다',
#   '올림픽',
#   '정신',
#   '인가요'],
#  ['말', '을', '총', '쏘다', '죽이다'],
#  ['올림픽',
#   '종목',
#   '정',
#   '기준',
#   '뭔가',
#   '요',
#   '나',
#   '올림픽',
#   '이제',
#   '무엇',
#   '을',
#   '상징',
#   '모르다',
#   '위선',
#   '적',
#   '인',
#   '게임',
#   '같다',
#   '느낌',
#   '온갖',
#   '비리',
#   '알',
#   '수',
#   '없다',
#   '종목',
#   '시대',
#   '변하다',
#   '만큼',
#   '올림픽',
#   '재정',
#   '비',
#   '되어다',
#   '필요',
#   '있다',
#   '보이다'],
#  ['말고기', '육회마렵', '네', 'ㅋㅋㅋㅋㅋㅋ', '저', '말', '새끼'],
#  ['저', '말', '노골', '적', '선수', '여럿', '조진', '경력', '있다', '그냥', '버리다', '안되다'],
#  ['동물권',
#   '이딴',
#   '소리',
#   '마편',
#   '사용',
#   '하용',
#   '아니다',
#   '이렇다',
#   '시대',
#   '뒤',
#   '떨어지다',
#   '종목',
#   '을',
#   '개편',
#   '해',
#   '라',
#   '진짜',
#   '이도',
#   '저',
#   '아니다',
#   '게',
#   '뭐',
#   '냐'],
#  ['다',
#   '들다',
#   '말',
#   '한테',
#   '뭐라다',
#   '생각',
#   '댓글',
#   '달다',
#   '선수',
#   '그렇지만',
#   '갑자기',
#   '이상하다',
#   '조형',
#   '물',
#   '을',
#   '놔두다',
#   '말',
#   '놀라다',
#   '게',
#   '노답',
#   '인',
#   '거지',
#   '괜히',
#   '죄',
#   '없다',
#   '말',
#   '만',
#   '계속',
#   '매질',
#   '당',
#   '하고',
#   '저런',
#   '종목',
#   '없어지다',
#   '필요',
#   '있다'],
#  ['사기', '치기', '딱', '좋다', '룰', '이네'],
#  ['게', '스포츠', '라고'],
#  ['말',
#   '교감',
#   '전쟁',
#   '시',
#   '적의',
#   '말',
#   '을',
#   '뺏다',
#   '타다',
#   '가정',
#   '만들다',
#   '말',
#   '선수',
#   '명령',
#   '을',
#   '안',
#   '따르다',
#   '다른',
#   '말',
#   '을',
#   '선택',
#   '권리',
#   '주다',
#   '전쟁',
#   '상이',
#   '면',
#   '그냥',
#   '총',
#   '쏘다',
#   '죽',
#   '이지',
#   '다른',
#   '말타',
#   '고',
#   '갈다'],
#  ['울다', '너', '무안', '스럽다', 'ㅜ', '달다'],
#  ['나', '같다', '개', '빡치다', '내려오다', '같다', '오다'],
#  ['내', '같다', '칼듵고와', '서', '말', '모가지', '내려쳣다'],
#  ['슬프다', '저', '날', '을', '위해', '서', '얼마나', '훈련'],
#  ['일본',
#   '이상하다',
#   '조형',
#   '물',
#   '너무',
#   '가다',
#   '놓다',
#   '말',
#   '정상',
#   '아니다',
#   '말',
#   '엄청',
#   '예민하다',
#   '동물',
#   '이라'],
#  ['정말',
#   '전시',
#   '이다',
#   '말다',
#   '듣다',
#   '말',
#   '목',
#   '을',
#   '칼',
#   '로',
#   '치다',
#   '않다',
#   '싶다',
#   '비슷하다',
#   '이야기',
#   '있다',
#   '같다'],
#  ['살다', '말', '가챠네이', '게', '스포츠', '냐', '도박', '이지'],
#  ['얼마나',
#   '말',
#   '혹사',
#   '당하다',
#   '말',
#   '복수',
#   '말',
#   '나름',
#   '생각',
#   '있다',
#   '생물',
#   '이다',
#   '말',
#   '을',
#   '다독이다',
#   '내',
#   '눈',
#   '에는',
#   '때리다',
#   '는걸',
#   '로',
#   '보이',
#   '네',
#   '사람',
#   '하나',
#   '안',
#   '불쌍하다',
#   '왜',
#   '울다',
#   '모르다',
#   '교감',
#   '무슨',
#   'ㅋㅋ'],
#  ['이런', '경우', '있다', '안타깝다'],
#  ['에이', '내', '왜', '란', '말', '말', '들리다', '듯', '하이'],
#  ['말', '을', '다독이다', '아니다', '쥐다', '박다'],
#  ['수년',
#   '을',
#   '준비',
#   '해오다',
#   '선수',
#   '한테',
#   '말',
#   '배정',
#   '방식',
#   '복불',
#   '이라니',
#   '게',
#   '경기',
#   '냐',
#   '집다',
#   '추다',
#   '말',
#   '선수',
#   '불쌍하다'],
#  [],
#  ['저건',
#   '잘못',
#   '되어다',
#   '봄',
#   '몇',
#   '년',
#   '동안',
#   '죽다',
#   '연습',
#   '올림픽',
#   '규정',
#   '때문',
#   '경기',
#   '망치다'],
#  ['그냥', '김유신', '처럼', '말', '목', '자르다', '안되다'],
#  ['전',
#   '시',
#   '상황',
#   '을',
#   '가정',
#   '거',
#   '면',
#   '뭔',
#   '동물학대',
#   '논함',
#   'ㅋㅋㅋㅋ',
#   '그냥',
#   '종목',
#   '을',
#   '없애다',
#   '또',
#   '개다',
#   '성',
#   '동물',
#   '권리',
#   '보호',
#   '단체',
#   '고기',
#   '애호가',
#   '몰려오다'],
#  ['저건', '선수', '말', '빠따', '로', '후려치다', '인정', '해주다', '야하다'],
#  ['그', '선수', '코치', '말', '을', '주먹', '때리다', '자격', '정지', '먹다', '대요'],
#  ['그냥', '바이크', '로', '바꾸다', '적군', '바이크', '뺏다', '설정'],
#  ['아무리',
#   '생각',
#   '해도',
#   '동물학대',
#   '인',
#   '것',
#   '같다',
#   '말',
#   '왜',
#   '채찍',
#   '질',
#   '을',
#   '당하다',
#   '장애물',
#   '을',
#   '넘다',
#   '말',
#   '안',
#   '들다',
#   '원망',
#   '까지',
#   '당하다'],
#  ['말고기', '해먹', '어', '라'],
#  ['동물', '때리다', '맞다'],
#  ['동물학대', '다', '반려견', '마찬가지'],
#  ['승마', '빼다', '너무', '안타깝다'],
#  ['일본말', '이라', '그', '런가', '일본말', '로', '해봤다', '어떻다'],
#  ['선수', '선수', '대로', '불쌍하다', '말', '말', '대로', '불쌍하다'],
#  ['말', '아', '왜', '그렇다', 'ㅠ'],
#  ['선수',
#   '안타깝다',
#   '싫다',
#   '이유',
#   '있다',
#   '채찍',
#   '질',
#   '당하다',
#   '말',
#   '너무',
#   '불쌍하다',
#   'ㅜㅜ',
#   '승마',
#   '장',
#   '말',
#   '보다',
#   '안장',
#   '맞닿다',
#   '등',
#   '피부',
#   '다',
#   '벗겨지다',
#   '얼마나',
#   '고통스럽다',
#   '너무',
#   '불쌍하다'],
#  ['없애다'],
#  ['금수', '저', '땡깡', '을', '같이', '공유', '정유', '라만', '생각나다'],
#  ['승마',
#   '안',
#   '동물',
#   '무슨',
#   '죄',
#   '야',
#   'ㅠㅠㅠ',
#   '공정',
#   '성도',
#   '없다',
#   '왜',
#   '게',
#   '스포츠',
#   '종목',
#   '들어가다',
#   '해안',
#   '간',
#   '다'],
#  ['승마',
#   '올림픽',
#   '종목',
#   '에서',
#   '빼다',
#   '말',
#   '기량',
#   '인',
#   '종목',
#   '라면',
#   '인간',
#   '스포츠',
#   '아니다',
#   '말',
#   '스포츠',
#   '이다',
#   '왜',
#   '인간',
#   '능력',
#   '을',
#   '겨루다',
#   '올림픽',
#   '에서',
#   '동물',
#   '기량',
#   '따르다',
#   '순위',
#   '정해지다'],
#  ['문재인', '애', '밉다', '뒤지다', '새끼', '북한', '지령', '대로', '움직임'],
#  ['ㅂㅅ', '갓', '울', '고', '그렇다'],
#  ['여기', '서', '때리다', '것', '같다'],
#  ['눈물', '이다', '나노', 'ㅜㅜ'],
#  ['에구', '얼마나', '속상하다', 'ㅜㅜ'],
#  ['말', '더', '불쌍하다', '듯', '싫다', '걸', '억지로', '듯'],
#  ['말', '끝나다', '도축', '되다'],
#  ['올림픽', '없어지다', '유물'],
#  ['넓적다리', '하나', '떼', '먹다', '정신차리다'],
#  ['독일', '가면', '육포', '행'],
#  ['복불복', '아니다', '게', '뭐', '냐'],
#  ['이건',
#   '운',
#   '실력',
#   '이다',
#   '늘다',
#   '아니다',
#   '운',
#   '실력',
#   '이다',
#   '올림픽',
#   '이네',
#   'ㅋㅋ',
#   '운',
#   '실력',
#   '이라는',
#   '말',
#   '실력',
#   '안',
#   '울다',
#   '운',
#   '없다',
#   '실력',
#   '없다',
#   '운',
#   '실력',
#   '인',
#   '거지',
#   'ㅋㅋ'],
#  ['도축', '마렵', '겠다'],
#  ['복불복',
#   '아니다',
#   '동물',
#   '길들이다',
#   '능력',
#   '임보',
#   '니까',
#   '안되다',
#   '울다',
#   '모르다',
#   '승마',
#   '하고',
#   '얼마',
#   '안되다',
#   '치다',
#   '뭔',
#   '감성',
#   '팔이',
#   '냐',
#   '진짜',
#   '그냥',
#   '멘탈',
#   '터지다',
#   '임',
#   '누캄프',
#   '기적',
#   '때',
#   '전반',
#   '끝나다',
#   '조르디',
#   '알바',
#   '치다',
#   '때',
#   '얼마나',
#   '조롱',
#   '당하다',
#   '그거',
#   '랑',
#   '다르다',
#   '바',
#   '없다'],
#  ['말', '에게도', '사정', '있다'],
#  ['질질', '짜다', '미치다', 'ㅋㅋㅋ'],
#  ['안타깝다', 'ㅜㅜ'],
#  ['가챠형', '종목', 'ㅋㅋㅋ'],
#  ['옛날',
#   '울',
#   '나라',
#   '선수',
#   '낙마',
#   '게',
#   '훨씬',
#   '더',
#   '놀라다',
#   '크다',
#   '날뻔',
#   '말',
#   '에게',
#   '깔리다',
#   '뻔'],
#  ['자기', '말로', '수', '있다', '해주다', '장난빠', '나'],
#  ['정도',
#   '면',
#   '승마',
#   '대체',
#   '바꾸다',
#   '야하다',
#   '같다',
#   '근대',
#   '니까',
#   '말',
#   '밖에',
#   '안되다',
#   '싸이클',
#   '근대',
#   '로',
#   '보다',
#   '없다'],
#  ['적의',
#   '말',
#   '을',
#   '빼앗다',
#   '탈',
#   '때',
#   '막',
#   '때리다',
#   '있다',
#   '저기',
#   '서',
#   '막',
#   '때리다',
#   '동물보호',
#   '안',
#   '학대',
#   '니',
#   '뭐라다',
#   '뭐라다',
#   '막',
#   '때리다',
#   '없다',
#   '운빨'],
#  ['전쟁', '중', '이다', '말', '대가리', '총알', '꽂히다'],
#  ['말', '제일', '관건', '이네'],
#  ['실력',
#   '이다',
#   '동물',
#   '단체',
#   '그렇다',
#   '교감',
#   '중요하다',
#   '그런고로',
#   '실력',
#   '맞음캣맘',
#   '그렇다',
#   '교감',
#   '중요하다',
#   '고개',
#   '빠',
#   '말',
#   '교감',
#   '중요하다',
#   '고개',
#   '통령',
#   '님',
#   '께',
#   '서도',
#   '교감',
#   '중요하다',
#   '그런고로',
#   '저',
#   '선수',
#   '실력',
#   '맞다'],
#  ['종목', '자체', '게', '사람', '실력', '아니다', '말', '실력', '아니다'],
#  ['말', '이제', '죽다', '있다'],
#  ['승마',
#   '해보다',
#   '알다',
#   '말',
#   '이랑',
#   '교감',
#   '게',
#   '정말',
#   '중요하다',
#   '말',
#   '처음',
#   '보다',
#   '사람',
#   '태우다',
#   '달리다',
#   '익숙하다',
#   '않다',
#   '저러다',
#   '것',
#   '같다',
#   '선수',
#   '분',
#   '말',
#   '안타깝다'],
#  ['안타깝다', '말', '뭔', '죄', '냐', '동물학대', '다'],
#  ['그냥',
#   '자기',
#   '훈련',
#   '말로',
#   '안되다',
#   '이해',
#   '안되다',
#   '실력',
#   '승부',
#   '스포츠',
#   '정신',
#   '갑자기',
#   '추첨',
#   '이라니',
#   '자기',
#   '열심히',
#   '해도',
#   '그날',
#   '말',
#   '컨디션',
#   '별로',
#   '인',
#   '건',
#   '누가',
#   '어떻다',
#   '알',
#   '지',
#   '그야말로',
#   '목숨',
#   '걸다',
#   '스포츠',
#   '네',
#   '바뀌다',
#   '필요',
#   '있다'],
#  ['자다', '아니다', '뽑다', '필요하다', '경기', '라'],
#  ['어마', '자기', '말로', '타다', '아니다'],
#  ['지우', '랑', '피카츄', '친해지다', '몇', '화가', '걸리다'],
#  ['말', '불쌍하다'],
#  ['희소성', '원칙', '개승엽새퀴', '막판', '치다', '나오다'],
#  ['근데',
#   '위험하다',
#   '말',
#   '훔치다',
#   '타다',
#   '저러다',
#   '필요',
#   '있다',
#   '분만',
#   '교감',
#   '니미',
#   '드루이드',
#   '그건',
#   '힘들다'],
#  ['말',
#   '과의',
#   '교감',
#   '같다',
#   '개',
#   '소리',
#   '하',
#   '네',
#   '몇',
#   '년',
#   '간',
#   '같이',
#   '연습',
#   '내',
#   '주인',
#   '님',
#   '말',
#   '고',
#   '갑자기',
#   '전혀',
#   '모르다',
#   '사람',
#   '이랑',
#   '경기',
#   '하',
#   '라고',
#   '입장',
#   '에서도',
#   '당연하다',
#   '거부',
#   '진짜',
#   '올림픽',
#   '종목',
#   '만들다',
#   '놈',
#   '대가리',
#   '뭐',
#   '들다',
#   '엇',
#   '늘다',
#   '모르다'],
#  ['다',
#   '좋다',
#   '마지막',
#   '이승협',
#   '머',
#   '지',
#   '더럽다',
#   '지',
#   '싸인',
#   '볼',
#   '아깝다',
#   '인간',
#   '얼굴',
#   '안',
#   '아깝다',
#   '가보다',
#   '아',
#   '야구',
#   '머',
#   '되다',
#   '기분',
#   '너무',
#   '좋다'],
#  ['교감', '개뿔', '그냥', '복불복', '운빨', '이지'],
#  ['스포츠', '뭔', '갓챠겜', '아니다', '복불복', '이라니', '말', '되다'],
#  ['게', '올림픽', '맞다'],
#  ['고유', '말', '패자'],
#  ['혹시', '못', '기다', '저', '경기장', '제국주의', '일본', '유물', '가득', '전쟁', '법죄', 'ㄷ'],
#  ['씹다', 'ㅈ', '같다', '만들다', '경기', '룰', '을'],
#  ['말',
#   '돈',
#   '많이',
#   '들어가다',
#   '부분',
#   '이라',
#   '자기',
#   '말로',
#   '하자',
#   '니',
#   '데려오다',
#   '비용',
#   '부터',
#   '난관',
#   '이고',
#   '경기',
#   '직전',
#   '말',
#   '을',
#   '제공',
#   '말',
#   '가챠',
#   '게임',
#   '되다',
#   '그렇다고',
#   '경기',
#   '전',
#   '본보기',
#   '로',
#   '말',
#   '안',
#   '들다',
#   '죽',
#   '을',
#   '수',
#   '있다',
#   '말',
#   '한테',
#   '경고',
#   '수',
#   '있다',
#   '것',
#   '아니다'],
#  ['말', '죽이다', '버리다', '진짜', 'ㅋㅋㅋ'],
#  ['동물학대', '마르다'],
#  ['선수', '울', '고', '있다', '보다', '말', '탓', '만은', '수', '없다'],
#  ['말', '그냥', '토막', '치다'],
#  ['무슨',
#   '이렇다',
#   '룰',
#   '종목',
#   '있다',
#   '말',
#   '어떻다',
#   '랜덤',
#   '이야',
#   '같다',
#   '파트너',
#   '로써',
#   '누가',
#   '자다',
#   '해내다',
#   '평가'],
#  ['동물', '인권', '우선', '입', '니까', '사람', '인권', '우선', '입', '니까'],
#  ['난', '개인', '적', '종목', '퍠', '지', '돼다', '좋다', '말', '개', '불쌍하다', '게뭐임'],
#  ['아', '진짜', '저', '선수', '무슨', '죄', '야', 'ㅠㅠ', '내', '다', '안쓰럽다'],
#  ['너무', '안타깝다', 'ㅜㅜ'],
#  ['문워크', '치다', '말', '이크', '잭슨'],
#  ['저', '말', '자격', '없다', '같다', '퇴', '시키다', '야하다'],
#  ['말',
#   '무슨',
#   '죄',
#   '이고',
#   '저',
#   '선수',
#   '무슨',
#   '죄인',
#   '선수',
#   '울음소리',
#   '너무',
#   '서글프다',
#   '들리다',
#   '이런',
#   '경우',
#   '말',
#   '을',
#   '한번',
#   '바꾸다',
#   '한번',
#   '더',
#   '수',
#   '있다',
#   '맞다',
#   '아니다',
#   '너무',
#   '불골평',
#   '하고',
#   '운',
#   '좌우',
#   '되다',
#   '경기',
#   '같다',
#   '그렇다'],
#  ['너무나',
#   '시',
#   '대',
#   '착오',
#   '적',
#   '이네',
#   '요',
#   '동물학대',
#   '임',
#   '에도',
#   '분명하다',
#   '싸이클',
#   '로',
#   '대체',
#   '하든',
#   '룰',
#   '을',
#   '바꾸다'],
#  ['튀김',
#   '왕',
#   '댓글',
#   '을',
#   '달',
#   '기전',
#   '제대로',
#   '기사',
#   '영상',
#   '보다',
#   '저',
#   '선수',
#   '코치',
#   '말',
#   '교감',
#   '하',
#   '라고',
#   '주어지다',
#   '분동',
#   '안',
#   '주먹',
#   '채찍',
#   '때리다',
#   '학대',
#   '추방',
#   '당하다',
#   '말',
#   '외',
#   '교통',
#   '수단',
#   '없다',
#   '시대',
#   '아니다',
#   '굳이',
#   '올림픽',
#   '동물',
#   '을',
#   '이용',
#   '경기',
#   '필요하다',
#   '대한',
#   '제',
#   '의견',
#   '이다',
#   '참고',
#   '로',
#   '전',
#   '베다',
#   '리언',
#   '이다'],
#  ['부터', '저', '선수', '울먹이다', '놓다', '왜', '이리', '슬프다', 'ㅠㅠ'],
#  ['ㄹㅇ', '말고기', '폭행', '해도', '무죄'],
#  ['경기', '끝나다', '말고기', '먹다', '버리다', '겠다', 'ㅠㅠ'],
#  ['말',
#   '과의',
#   '교감',
#   '중요하다',
#   '시간',
#   '을',
#   '충분하다',
#   '주다',
#   '말',
#   '교감',
#   '안되다',
#   '바꾸다',
#   '넉넉하다',
#   '시간',
#   '을',
#   '주다',
#   '좋다',
#   '같다'],
#  ['말',
#   '이번',
#   '유독',
#   '저렇게',
#   '장애물',
#   '을',
#   '안',
#   '뛰어넘다',
#   '이유',
#   '저',
#   '흉칙',
#   '장애물',
#   '때문',
#   '이르다',
#   '지금',
#   '경기장',
#   '보다',
#   '일',
#   '본',
#   '놈',
#   '스모',
#   '선수',
#   '지네',
#   '나라',
#   '홍보물',
#   '로',
#   '도배',
#   '함',
#   '자세하다',
#   '보',
#   '니까',
#   '나다',
#   '무섭다',
#   '음',
#   '하'],
#  ['말', '다루다', '실력', '안되다', '아니다'],
#  ['아니다', 'ㅅㅂ', '말', '복불복', '라고', '처음', '알다', '네', '웃픈', '영', '상이', '네', '요'],
#  ['하여튼', '일', '본', '놈', '저', '말', '을'],
#  ['운', '만', '좋다', '금메달', '을', '딸', '수', '있다', '종목', '있다', '뿌슝빠슝'],
#  ['로봇', '말', '같다', '나오다', '않다', '이상', '공정하다', '힘들다', 'ㅜ'],
#  ['말', '싫다', '잔', '아', '채찍', '학대', '하니', '싶다', '못', '되다', '인간', '아'],
#  ['스포츠', '아니다', '경기', '하나', '통제', '안되다', '어쩌란', '말', '인가'],
#  ['올림픽', '챠', '말', '듣다', '말', '뽑다', '확률', '을', '늘다', '공개', '하라'],
#  ['말', '아', '말', '듣다', 'ㅠㅠ'],
#  ['교감', '단시간', '에도', '대체', '왜', '올림픽', '폐지'],
#  ['말', '친해지다', '것', '능력', '이기다', '데', '너무', '운', '달다'],
#  ['자다', '보다', '왜', '짜증나다', '마지막', '이승엽', '나오다'],
#  ['동물',
#   '을',
#   '사람',
#   '맘대로',
#   '조종',
#   '자체',
#   '동물',
#   '을',
#   '사람',
#   '밑',
#   '두다',
#   '하등',
#   '대다',
#   '반려견',
#   '이라고',
#   '동물',
#   '키우다',
#   '지다',
#   '싶다',
#   '반려견',
#   '을',
#   '맘대로',
#   '컨트롤',
#   '자체',
#   '잘못',
#   '된거',
#   '지',
#   'ㅋㅋㅋ',
#   '내',
#   '그래서',
#   '반려',
#   '동물',
#   '키우다',
#   '사람',
#   '을',
#   '쥰내',
#   '싫어하다',
#   'ㅋㅋ',
#   '이렇다',
#   '섹희들',
#   '쥰내',
#   '기적',
#   '인',
#   '섹',
#   '희다',
#   '들이다',
#   'ㅋㅋ'],
#  ['개빠충들'],
#  ['지',
#   '말',
#   '을',
#   '대리',
#   '고',
#   '오다',
#   '저',
#   '게',
#   '복불복',
#   '이지',
#   '말',
#   '에다가',
#   '약',
#   '타',
#   '먹이',
#   '면',
#   '끝'],
#  ['패', '죽이다'],
#  ['저런', '말', '즉각', '총살', '답', '이다'],
#  ['오함마', '로', '말', '대갈', '통', '을', '뽀개야', '지'],
#  ['동물',
#   '좋아하다',
#   '치킨',
#   '삼겹살',
#   '양보',
#   '수',
#   '없다',
#   '씹다',
#   '개다',
#   '성',
#   '파',
#   '개돼지',
#   '새끼',
#   '댓글',
#   '보',
#   '니까',
#   '역겹다'],
#  ['안타깝다', '한데', '어쩌겠어'],
#  ['동물',
#   '가지',
#   '고',
#   '경기',
#   '것',
#   '왠지',
#   '싫다',
#   '게',
#   '네',
#   '들이다',
#   '메달',
#   '따다',
#   '것',
#   '아니다'],
#  ['말', '안되다', '올림픽', '종목', '많다', '로비', '결과', '라고', '봄', '시발', '새끼'],
#  ['말고기', '바로', '진심'],
#  ['경기',
#   '장애물',
#   '오브',
#   '제',
#   '뭐',
#   '저따위',
#   '인지',
#   '사람',
#   '모양',
#   '별',
#   '모양',
#   '다',
#   '있다',
#   '말',
#   '안',
#   '놀라다',
#   '신기하다',
#   'ㅋㅋ'],
#  ['말',
#   '이랑',
#   '친해지다',
#   '종목',
#   '이래',
#   'ㅋㅋㅋㅋ',
#   '싀펄',
#   '불다',
#   '사람',
#   '이랑',
#   '친해지다',
#   '힘드다',
#   '동물',
#   '이랑',
#   '무슨',
#   '말',
#   '통',
#   '뭐',
#   '눈빛',
#   '교환',
#   '하',
#   '냐',
#   'ㅋㅋㅋㅋㅋ',
#   '그냥',
#   '운빨',
#   '로',
#   '시합'],
#  ['이런', '걸', '왜함'],
#  ['말고기', '되어다'],
#  ['패', '면', '말', '들을턴디'],
#  ['아', 'ㅜㅠㅠㅠ', '울다', '보', '니까', '맘', '아프다'],
#  ['아이고', '속상하다', '죽겠네'],
#  ['승마', '빼다', '게', '나다', '듯'],
#  ['분전', '추첨', '배당', '되다', '말', '정말', '문제', '있다', '종목', '이네', '요'],
#  ['운',
#   '실력',
#   '이라고',
#   '빡',
#   '대가리',
#   '많다',
#   '운',
#   '어케실력',
#   '이냐',
#   '단어',
#   '뜻',
#   '모름',
#   '운',
#   '말',
#   '그대로',
#   '운일',
#   '뿐',
#   '이지',
#   '꼭',
#   '실력',
#   '없이',
#   '운',
#   '좋다',
#   '뭔가',
#   '득',
#   '본',
#   '사람',
#   '개',
#   '소리',
#   '지껄이다',
#   '때',
#   '운',
#   '실력',
#   '이다',
#   '라고',
#   '변명'],
#  ['거', '진짜', '말빨', '종목', '이네'],
#  ['보다', '내', '다', '안타깝다', '얼마나', '속상하다'],
#  ['이순신장군', '이다', '말', '모가지', '그냥', 'ㅋㅋ'],
#  ['아', '너무', '안타깝다', 'ㅜ', '울', '지', '말다', '당신', '이미', '챔피언', '이다'],
#  ['현대',
#   '너무',
#   '안',
#   '맞다',
#   '경기',
#   '경기',
#   '방식',
#   '그렇다고',
#   '빼다',
#   '이건',
#   '창시자',
#   '직접',
#   '제안',
#   '종목',
#   '거기',
#   '다',
#   '올림픽',
#   '상업',
#   '화',
#   '견제',
#   '라는',
#   '의미',
#   '가지다',
#   '종목',
#   '현대',
#   '맞다',
#   '수정',
#   '큰일',
#   '이니',
#   '오랜',
#   '시간',
#   '듬',
#   '현재',
#   '올림픽',
#   '인기',
#   '없다',
#   '운빨겜'],
#  ['뜬금없이', '이승엽', '저리', '가라', 'ㅅㄲ', '야'],
#  ['짧다',
#   '시간',
#   '말',
#   '과의',
#   '교감',
#   '을',
#   '얻엇',
#   '니',
#   '내',
#   '편',
#   '만들다',
#   '훈련',
#   '운',
#   '만이',
#   '아니다',
#   '보다'],
#  ['말', '얼마나', '스트레스', '받다'],
#  ['올림픽',
#   '도박',
#   '재미',
#   '아니다',
#   '실력',
#   '보다',
#   '운',
#   '좌지우지',
#   '되게',
#   '만들다',
#   '놓다',
#   '눈물',
#   '흘리다',
#   '재미있다'],
#  ['안타깝다',
#   '진짜',
#   '근데',
#   '가챠겜',
#   '여기',
#   '있다',
#   '모바일',
#   '게임',
#   '욕',
#   '하므다',
#   '안되다',
#   '세계',
#   '적',
#   '인',
#   '가챠겜',
#   'ㅎㅎ'],
#  ['말',
#   '볼때',
#   '마다',
#   '느끼다',
#   'ㄹㅇ',
#   '소시오패스',
#   '빡통',
#   '대가리',
#   '라',
#   '는걸',
#   '맨날',
#   '느낌',
#   'ㅋㅋㅋㅋ'],
#  ['자꾸',
#   '운',
#   '이라고',
#   '애초',
#   '우리',
#   '태어나다',
#   '때',
#   '부터',
#   '운빨',
#   '중요하다',
#   '누구',
#   '운동',
#   '알맞다',
#   '재능',
#   '을',
#   '가지',
#   '고',
#   '태어나다',
#   '누구',
#   '병약하다',
#   '태어나다',
#   '재능',
#   '없다',
#   '노력',
#   '극복',
#   '노력',
#   '재능',
#   '이야',
#   '인간',
#   '신체',
#   '생체',
#   '주기',
#   '따르다',
#   '당일',
#   '컨디션',
#   '다르다',
#   '운빨',
#   '없다',
#   '경기',
#   '어딧너'],
#  ['동물',
#   '개입',
#   '시키다',
#   '말고',
#   '인간',
#   '힘',
#   '으로만',
#   '경기',
#   '치르다',
#   '좋다',
#   '양쪽',
#   '다',
#   '민폐',
#   '임'],
#  ['너무',
#   '마음',
#   '아프다',
#   '규정',
#   '을',
#   '변경',
#   '아니다',
#   '선수',
#   '울음소리',
#   '제',
#   '맘',
#   '을',
#   '흔들다',
#   '같다',
#   '얼마나',
#   '땀',
#   '흘리다',
#   '노력',
#   '그런데',
#   '그것',
#   '을',
#   '운',
#   '결정',
#   '한다는',
#   '건',
#   '너무',
#   '아니다',
#   '같다'],
#  ['뭐',
#   '이렇다',
#   '말',
#   '안되다',
#   '경기',
#   '다',
#   '있다',
#   '승마',
#   '빼다',
#   '다른',
#   '종목',
#   '을',
#   '넣다',
#   '누가',
#   '저런',
#   '걸',
#   '만들다',
#   '자신',
#   '말로',
#   '경기도',
#   '아니다',
#   '뭐',
#   '야',
#   '도대체',
#   '선수',
#   '잡다',
#   '경기',
#   '네'],
#  ['너무', '위험하다'],
#  ['승마',
#   '자체',
#   '말',
#   '안되다',
#   '뻘짓',
#   '이지',
#   '게',
#   '생명',
#   '존중',
#   '측면',
#   '짓',
#   '인가요',
#   '경주마',
#   '시합',
#   '후',
#   '체중',
#   '감소',
#   '수십',
#   '랍',
#   '니',
#   '다',
#   '혹시',
#   '경마',
#   '공원',
#   '은퇴식',
#   '들다',
#   '보셧나',
#   '요',
#   '아무리',
#   '성적',
#   '안',
#   '좋다',
#   '말',
#   '사람',
#   '안',
#   '해주다',
#   '은퇴식',
#   '꼬옥',
#   '해주다',
#   '못',
#   '짓',
#   '시키다',
#   '미안하다',
#   '말',
#   '체중',
#   '정도',
#   '로',
#   '알',
#   '고',
#   '있다',
#   '거',
#   '채찍',
#   '때리다',
#   '수',
#   '미터',
#   '장애물',
#   '뛰다',
#   '넘다'],
#  ['시합', '이후', '체중', '감소', '수십', '말', '한테', '늘다', '고통', '이겠다'],
#  ['오다', '짐승', '이지만', '너', '진짜', '너무하다'],
#  ['빡',
#   '대가리',
#   '새끼',
#   '아',
#   '랜덤',
#   '말타',
#   '기도',
#   '다',
#   '경기',
#   '일환',
#   '거지',
#   '경기',
#   '룰',
#   '가지',
#   '고',
#   '가타',
#   '부타',
#   '아',
#   '갈다',
#   '털다',
#   '마르다',
#   '뭘',
#   '안다',
#   '떠들다'],
#  ['마음', '아프다', 'ㅜㅜ'],
#  ['말',
#   '그냥',
#   '독산동',
#   '우시',
#   '장',
#   '아니다',
#   '마장동',
#   '보내다',
#   '오늘',
#   '저녁',
#   '에는',
#   '말고기',
#   '잡다'],
#  ['저', '말', '불쌍하다'],
#  ['말', '기분', '금메달', '을', '결정', '경기', '이다'],
#  ['말', '더', '불쌍하다'],
#  ['동물', '을', '쓰다', '종목', '없어지다', '좋다', 'ㅠㅠ'],
#  ['슐로이', '저녁', '말고기', '겠다'],
#  ['승마', '빼다', '맞다', '본인', '노력', '외', '변수', '너무', '많다'],
#  ['말', '배정은', '개', '같다', '그', '동안', '연습', '게', '너무', '허무하다'],
#  ['그래도', '올림픽', '선수', '란', '사람', '저렇게', '울다', '쫌'],
#  ['말', '학대', '그만', '인간', '정신', '챙기다'],
#  ['돼지고기', '소고기', '자다', '먹다'],
#  ['오다',
#   '대박',
#   '이다',
#   'ㅡ',
#   '자다',
#   '아니다',
#   '말로',
#   '경주',
#   '대다',
#   '분',
#   '간',
#   '교류',
#   '대다',
#   '동물',
#   '말',
#   '습득',
#   'ㅋㅋ'],
#  ['인간',
#   '친하다',
#   '개도',
#   '주인',
#   '을',
#   '받아들이다',
#   '시간',
#   '들다',
#   '하물며',
#   '경주마',
#   '저건',
#   '말',
#   '안',
#   '되다',
#   '경기',
#   '다'],
#  ['말',
#   '잘나다',
#   '사람',
#   '잘나다',
#   '동물',
#   '동물',
#   '일',
#   '뿐',
#   '의인화',
#   '시키다',
#   '인간',
#   '따위',
#   '컨트롤',
#   '수',
#   '없다'],
#  ['승마',
#   '정유',
#   '라가',
#   '타다',
#   '문',
#   '재앙',
#   '패거리',
#   '없다',
#   '죄',
#   '뒤지다',
#   '씌우다',
#   '범죄자',
#   '만들다',
#   '바람',
#   '에이번',
#   '국정원',
#   '의하다',
#   '재앙',
#   '선거',
#   '운동',
#   '때',
#   '간첩',
#   '새',
#   '키도',
#   '나왓',
#   '다지',
#   '재앙',
#   '이다',
#   '재앙',
#   '로다'],
#  ['말', '노쇼', '하', '일', '본', '동물', '본능', '이란', '무섭다', '잔인하다', '가차', '없다'],
#  ['경',
#   '기전',
#   '코치',
#   '말',
#   '을',
#   '오지',
#   '게',
#   '패',
#   '서',
#   '그런',
#   '거',
#   '라네',
#   '요',
#   '그',
#   '코치',
#   '올림픽',
#   '에서',
#   '퇴',
#   '추다',
#   '고요'],
#  ['말',
#   '을',
#   '자다',
#   '다루다',
#   '말',
#   '조련사',
#   '돼다',
#   '처음',
#   '보다',
#   '말',
#   '이랑',
#   '교감',
#   '돼다',
#   '애니멀',
#   '커뮤',
#   '니',
#   '케이',
#   '터',
#   'ㅋㅋㅋ',
#   '선수',
#   '부상',
#   '입다',
#   '말',
#   '학대',
#   '나',
#   '마찬가지',
#   '인데',
#   '시대',
#   '덜',
#   '떨어지다',
#   '종목',
#   '임'],
#  ['말', '생기다', 'ㅈㄴ', '말다', '듣다', '생기다', 'ㅋㅋㅋㅋ'],
#  ['이렇게',
#   '승마',
#   '사람',
#   '아니다',
#   '말',
#   '것임',
#   '증명',
#   '돼다',
#   '사람',
#   '의지',
#   '로',
#   '아무',
#   '것',
#   '못'],
#  ['정말', '안', '돼다', '다말', '한테', '뭐라다', '없다', '짠하다'],
#  ['어떡하다', '열심히', '준비', '내', '다', '속상하다'],
#  ['말빨', 'ㅈ', '망겜'],
#  ['가위바위보',
#   '비슷하다',
#   '건가',
#   '아무리',
#   '선수',
#   '경기',
#   '날',
#   '자신',
#   '말로',
#   '뛰다',
#   '않다',
#   '이상',
#   '운',
#   '좋다',
#   '나쁘다',
#   '따르다',
#   '다르다',
#   '선수',
#   '울다',
#   '모',
#   '습보',
#   '니깐',
#   '맘',
#   '아프다',
#   'ㅠ',
#   '상위',
#   '권',
#   '라며',
#   '저',
#   '선수',
#   'ㅠ'],
#  ['아니다',
#   '외신',
#   '을',
#   '보다',
#   '말',
#   '과의',
#   '교감',
#   '을',
#   '얼마나',
#   '자다',
#   '측정',
#   '스포츠',
#   '이고',
#   '교감',
#   '안되다',
#   '못',
#   '달리',
#   '면',
#   '공동',
#   '책임',
#   '내지',
#   '선수',
#   '책임',
#   '스포츠',
#   '목적',
#   '그것',
#   '이니',
#   '이지',
#   '취지',
#   '벗어나다',
#   '무조건',
#   '재수없다',
#   '말',
#   '마리',
#   '때문',
#   '사람',
#   '인생',
#   '말',
#   '아',
#   '먹다',
#   '처럼',
#   '원',
#   '취지',
#   '어긋나다',
#   '않다',
#   '말',
#   '안',
#   '듣다',
#   '주먹',
#   '때리다',
#   '채찍',
#   '휘두르다',
#   '저',
#   '선수',
#   '코치',
#   '이다',
#   '미안하다'],
#  ['승마', 'ㅅㅂ', '내', '의지', '상관없다', '나', '종목', '에서', '빼', '라', 'ㅂㅅ', '같다'],
#  ['옆', 'ㅡ', '코치', '년', '인가', 'ㅡ', '주먹', '말', '주다', '패', '네'],
#  ['저', '말', '바로', '죽', '여서', '고기', '로', '만들다'],
#  ['이건', '말', '선수', '에게도', '잔인하다'],
#  ['비융',
#   '신의',
#   '나라',
#   '일본',
#   '이렇다',
#   '나라',
#   '한국',
#   '보다',
#   '더',
#   '좋아하다',
#   'ㅇㅅㅇ',
#   'ㅎㄱㅇ',
#   '보수'],
#  ['문', '재앙'],
#  ['다시', '희망', '찬', '얼굴', '더욱더', '슬프다', '만드', '네'],
#  ['우리',
#   '한테',
#   '나',
#   '훈련',
#   '이고',
#   '스포츠',
#   '지',
#   '가두다',
#   '겁나다',
#   '굳다',
#   '대',
#   '고배',
#   '비행기',
#   '태우다',
#   '끄다',
#   '자꾸',
#   '오르다',
#   '타다',
#   '달리',
#   '라',
#   '입장',
#   '에선',
#   'ㅈ',
#   '같다',
#   '같다'],
#  ['말', '긴장'],
#  ['랜덤', '박스', 'ㅋㅋ'],
#  ['처음',
#   '보다',
#   '말',
#   '다루다',
#   '니',
#   '네',
#   '좋아하다',
#   '교감',
#   '실력',
#   '인데',
#   '왜',
#   '말탓',
#   '이냐',
#   '올림픽',
#   '준비',
#   '되다',
#   '정도',
#   '말',
#   '이면',
#   '어느',
#   '정도',
#   '검증',
#   '되다',
#   '말',
#   '들이다',
#   '텐데',
#   '왜',
#   '말',
#   '을',
#   '못',
#   '다루다',
#   '실력',
#   '이지',
#   '운',
#   '이냐',
#   '마장',
#   '에서',
#   '일',
#   '사람',
#   '피다',
#   '솓'],
#  ['말',
#   '눈',
#   '거의',
#   '뒤집힌',
#   '상태',
#   '에다가',
#   '웃다',
#   '표정',
#   '을',
#   '보이',
#   '면',
#   '경기',
#   '중이',
#   '나',
#   '그',
#   '전',
#   '극도',
#   '스트레스',
#   '받다',
#   '것',
#   '이다',
#   '말',
#   '저렇게',
#   '되다',
#   '이상',
#   '사람',
#   '교감',
#   '없다',
#   '경지',
#   '에요',
#   '저건',
#   '실력',
#   '을',
#   '넘어서다',
#   '운',
#   '안',
#   '따르다',
#   '맞다'],
#  ['다시',
#   '올리다',
#   '외국',
#   '뉴스',
#   '보다',
#   '저',
#   '선수',
#   '하고',
#   '코치',
#   '비난',
#   '일색',
#   '이다',
#   '선수',
#   '코치',
#   '말',
#   '을',
#   '주먹',
#   '치다',
#   '경',
#   '기',
#   '개입',
#   '동물학대',
#   '로',
#   '즉각',
#   '선수촌',
#   '퇴',
#   '추다',
#   '당하다',
#   '선수',
#   '말',
#   '안',
#   '듣다',
#   '울면',
#   '서',
#   '채찍',
#   '치다',
#   '동물학대',
#   '로',
#   '추가',
#   '징계',
#   '검토',
#   '중이',
#   '랍니',
#   '다',
#   '저',
#   '말',
#   '예전',
#   '에도',
#   '러시아',
#   '선수',
#   '말',
#   '안',
#   '들다',
#   '적',
#   '있다',
#   '경기',
#   '일부',
#   '라는',
#   '군',
#   '요',
#   '기사',
#   '보다',
#   '말',
#   '교감',
#   '을',
#   '능력',
#   '을',
#   '측정',
#   '것',
#   '인데',
#   '동물',
#   '학대',
#   '모습',
#   '을',
#   '보이다',
#   '스포츠',
#   '정신',
#   '심하다',
#   '위반',
#   '뭐',
#   '이르다',
#   '거참'],
#  ['얼마나', '썩다', '문제', '있다', '말', '또', '쓰다', '생각', '없다', '건가'],
#  ['맞다',
#   '선수',
#   '코치',
#   '말',
#   '을',
#   '때리다',
#   '동물',
#   '학대',
#   '이슈',
#   '있다',
#   '여기',
#   '서',
#   '조금',
#   '재미있다',
#   '저',
#   '말',
#   '을',
#   '타다',
#   '모든',
#   '선수',
#   '경마',
#   '부문',
#   '에서',
#   '점',
#   '을',
#   '받다',
#   '말',
#   '은근',
#   '고집',
#   '있다'],
#  ['동물학대',
#   '그렇게',
#   '생각',
#   '종목',
#   '에서',
#   '승마',
#   '빼다',
#   '요즘',
#   '전쟁',
#   '누가',
#   '말',
#   '타다',
#   '선수',
#   '코치',
#   '없다',
#   '징계',
#   '상황',
#   '왜',
#   '벌어지다',
#   '생각',
#   '해보다',
#   '야하다'],
#  ['선수',
#   '선',
#   '순',
#   '데',
#   '나',
#   '말',
#   '더',
#   '불쌍하다',
#   '얼마나',
#   '질리다',
#   '버리다',
#   '저렇게',
#   '악',
#   '을',
#   '쓰다',
#   '안'],
#  ['말고기', '먹다'],
#  ['초', '말', '똥말'],
#  ['쫌', '장애물', '디자인', '을', '클래식', '안대', '나', '정신', '존나', '사납다', '만들다'],
#  ['승마',
#   '없어지다',
#   '종목',
#   '사람',
#   '앉다',
#   '체칙질',
#   '을',
#   '조종',
#   '뿐',
#   '말',
#   '이다',
#   '승마',
#   '기',
#   '냥',
#   '돈',
#   '많다',
#   '사람',
#   '취미',
#   '생활',
#   '이나',
#   '하',
#   '는걸',
#   '로'],
#  ['장애물', '디자인', '말', '에게', '거부', '감', '주다', '일본', 'ㅈ', '같다'],
#  ['말', '일본', '에서는', '뛰다', '않다'],
#  ['게', '스포츠', '우욱'],
#  ['일본말', '더러', '지게', '말다', '듣다'],
#  ['이해',
#   '알다',
#   '말',
#   '개다',
#   '써다',
#   '몇',
#   '마리',
#   '선수',
#   '돌아가다',
#   '쓰다',
#   '말',
#   '되다',
#   '누',
#   '군',
#   '뛰어나다',
#   '쓰다',
#   '누',
#   '군',
#   '말다',
#   '듣다',
#   '쓰다',
#   '되다',
#   '교감',
#   '이아',
#   '니',
#   '라',
#   '어떻다',
#   '따르다',
#   '승패',
#   '좌지우지',
#   '되다',
#   '같다'],
#  ['나다', '못', '참다', '빽', '초크', '걸다', 'ㅆㅂ'],
#  ['자막',
#   '말',
#   '다독이다',
#   '화면',
#   '채찍',
#   '말',
#   '패',
#   '고',
#   '있다',
#   '도대체',
#   'ㅋㅋ',
#   '종목',
#   '없애다',
#   '맞다'],
#  ['너무',
#   '가슴',
#   '아프다',
#   '추첨',
#   '배정',
#   '받다',
#   '모르다',
#   '경주마',
#   '처럼',
#   '자기',
#   '말',
#   '쓰다',
#   '줄',
#   '알다',
#   '슬프다'],
#  ['지', '말로', '저건', '그렇다'],
#  ['왜',
#   '랜덤',
#   '배정',
#   '모르다',
#   '오랜',
#   '기간',
#   '동안',
#   '훈련',
#   '하고',
#   '배우다',
#   '습득',
#   '랜덤',
#   '배정',
#   '올림픽',
#   '맞다',
#   '싶다',
#   '전쟁',
#   '터',
#   '나가다',
#   '때',
#   '랜덤',
#   '배정',
#   '보병',
#   '해병',
#   '공군',
#   '없이',
#   '전쟁',
#   '터',
#   '나가다',
#   '싶다',
#   '해군',
#   '인데',
#   '보병',
#   '갈래',
#   '보병',
#   '인데',
#   '공군',
#   '갈래',
#   '공군',
#   '인데',
#   '해군',
#   '갈래',
#   '말',
#   '이랑',
#   '친해지다',
#   '한다는',
#   '건',
#   '알다',
#   '생판',
#   '남',
#   '이랑',
#   '호흡',
#   '안',
#   '맞다',
#   '올림픽',
#   '롤',
#   '왜',
#   '저렇다',
#   '랜덤',
#   '맞다',
#   '짜다',
#   '치다',
#   '아니다'],
#  ['말', '표정', '개', '빡치다', 'ㅋㅋㅋ'],
#  ['진짜',
#   'ㅈ',
#   '같다',
#   '경기',
#   '임',
#   '다르다',
#   '다',
#   '자기',
#   '실력',
#   '인데',
#   '승마',
#   '말',
#   '경',
#   '기',
#   '시',
#   '작',
#   '분전',
#   '복불복',
#   '랜덤',
#   '배정',
#   'ㅋ',
#   '저',
#   '게',
#   '실력',
#   '이냐',
#   '운빨',
#   'ㅈ',
#   '망',
#   '게임',
#   '이지'],
#  ['ㄹㅇ'],
#  ['일본말', '여서', '그렇다', '말', '드럽다', '안', '듣다', '똥꼬', '집', '만', '드럽다', '세다'],
#  ['말', '존재', '의미', '본래', '인간', '말', '을', '듣기', '위', '건', '아니다', '터'],
#  ['어이',
#   '없다',
#   '본인',
#   '말',
#   '아니다',
#   '본인',
#   '말',
#   '이라',
#   '장거리',
#   '동시',
#   '컨디션',
#   '크다',
#   '타',
#   '격감',
#   '을',
#   '입히다',
#   '종목',
#   '에서',
#   '동물',
#   '을',
#   '이용',
#   '것',
#   '없어지다',
#   '되다'],
#  ['그냥',
#   '꼰대룰',
#   '말리다',
#   '거지',
#   '애초',
#   '개인실',
#   '력',
#   '무작위',
#   '운',
#   '을',
#   '적용',
#   '한다는',
#   '게',
#   '말',
#   '되다',
#   '전통',
#   '말다',
#   '듣다',
#   '말',
#   '옛날',
#   '엔',
#   '맞다',
#   '뒤지다'],
#  ['오다', '걸', '그대로', '찍다', '버리다'],
#  ['희소성', '구독', '좋다', '구걸', '안', '안되다'],
#  ['이승', '여비', '저리', '가라'],
#  ['그렇게',
#   '준비',
#   '올림픽',
#   '인데',
#   '말',
#   '말',
#   '을',
#   '안',
#   '들어서다',
#   '회의',
#   '감',
#   '장난',
#   '아니다'],
#  ['애초',
#   '스포츠',
#   '경기',
#   '랑',
#   '전쟁',
#   '상황',
#   '을',
#   '동',
#   '일선',
#   '상',
#   '두다',
#   '지금',
#   '시대',
#   '상',
#   '에는',
#   '맞다',
#   '않다',
#   '듯'],
#  ['룰', '개다', 'ㅋㅋㅋ'],
#  ['선수', '안타깝다', '말', '입장', '에서', '이야기', '들다', '보다', '야하다'],
#  ['적',
#   '말',
#   '을',
#   '빼앗다',
#   '타다',
#   '거',
#   '면',
#   '군마',
#   '데려오다',
#   '맞다',
#   '전쟁',
#   '당시',
#   '적',
#   '말',
#   '빼앗다',
#   '장애물',
#   '달리기',
#   '하나',
#   '만',
#   '생각',
#   '하고',
#   '다르다',
#   '생각',
#   '안',
#   '종목',
#   '인',
#   '것',
#   '같다'],
#  ['개인', '적', '룰', '수정', '필요', '있다', '보임'],
#  ['아니다', '말', '을', 'ㅈㄴ', '떼다', '네', 'ㅋㅋㅋㅋ', '저', '거', '개', '아픔'],
#  ['운', '실력', '이지', 'ㅂㅅ', 'ㅋ'],
#  ['코치', '주먹', '말', '때리다', 'ㅜㅜ'],
#  ['그냥', '종목', '퇴', '출하', '고', '야구', '다시', '넣다', '안', '되다'],
#  ['하', '족발', '이나', '먹다', '가야', '지'],
#  ['정유',
#   '라는',
#   '조',
#   '민',
#   '비',
#   '정말',
#   '실력',
#   '있다',
#   '너머',
#   '억울하다',
#   '조',
#   '민',
#   '빨리',
#   '입학',
#   '취소',
#   '해',
#   '라',
#   '고려대',
#   '부산',
#   '대',
#   '쓰레기',
#   '아'],
#  ['곰탱이',
#   '조',
#   '민',
#   '인턴',
#   '어쩌',
#   '고',
#   '저쩌',
#   '고',
#   'ㅈㄹ',
#   '말고',
#   '그렇게',
#   '떳떳하다',
#   '고딩',
#   '때',
#   '성적',
#   '끄다',
#   '열심히',
#   '노력',
#   '살다',
#   '한영외고',
#   '고려대',
#   '시절',
#   '성적',
#   '한번',
#   '시원하다',
#   '깝시',
#   '다'],
#  ['곰탱이', '아시안', '게임', '금메달', '리스트'],
#  ['정유', '라가', '그래서', '맞다', '임'],
#  ['말', '시발', '새끼', '안락사', '시키다'],
#  ['너무', '위험하다', '승마', '빼다'],
#  ['가시', '몽둥이', '로', '바꾸다', '되다'],
#  ['강형욱',
#   '힘',
#   '말다',
#   '듣다',
#   '개새끼',
#   '다루다',
#   '이유',
#   '있다',
#   '말다',
#   '듣다',
#   '것',
#   '몽둥이',
#   '맛좀',
#   '보이다'],
#  ['고생',
#   '많다',
#   '다음',
#   '기회',
#   '있다',
#   '모르다',
#   '이번',
#   '일이',
#   '액땜',
#   '지나가다',
#   '여기다',
#   '더',
#   '멋지다',
#   '모습',
#   '보여주다',
#   '기대하다'],
#  ['독일', '선진국', '이라', '국가', '에서', '위로', '차원', '에서', '보상', '해주다'],
#  ['수',
#   '십년',
#   '간',
#   '노력',
#   '겨우',
#   '말',
#   '성질',
#   '머리',
#   '하나로',
#   '망가지다',
#   '물올',
#   '려',
#   '라',
#   '오늘',
#   '수육',
#   '이랑',
#   '사시미',
#   '두다',
#   '해먹',
#   '게',
#   '말고기',
#   '맛좀',
#   '보다'],
#  ['진짜',
#   '대가리',
#   '물',
#   '차다',
#   '저',
#   '게',
#   '말',
#   '못',
#   '이다',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅅㅂ',
#   '말',
#   '뒷돈',
#   '주다',
#   '버티다',
#   '요',
#   '구함'],
#  ['도축장',
#   '가다',
#   '즈',
#   '아',
#   '어',
#   '데',
#   '동물',
#   '새끼',
#   '말',
#   '을',
#   '안',
#   '듣다',
#   '한국',
#   '아니다',
#   '음',
#   '을',
#   '다행',
#   '인',
#   '줄',
#   '알다',
#   '된장',
#   '발리다',
#   '전',
#   'ㅋㅋ'],
#  ['진짜',
#   '이런',
#   '새',
#   '기',
#   '씨발',
#   '놈임',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '사람',
#   '인걸',
#   '다행',
#   '사다',
#   '그냥',
#   '진짜',
#   '로'],
#  ['운빨', 'ㅈ', '망겜', '여기', '있다'],
#  ['삼성', '에서', '말', '을', '지원', '받다', '어떻다'],
#  ['저',
#   '랜덤',
#   '배정',
#   '하',
#   '이유',
#   '승마',
#   '귀족',
#   '스포츠',
#   '라서',
#   '돈빨',
#   '이라서',
#   '그렇다',
#   '저',
#   '선수',
#   '에겐',
#   '안타깝다',
#   '저렇게',
#   '안',
#   '승마',
#   '돈',
#   '많다',
#   '선수',
#   '혹은',
#   '국가',
#   '유리하다',
#   '선수',
#   '역량',
#   '아니다',
#   '말',
#   '역량',
#   '이라서'],
#  ['시대',
#   '맞다',
#   '규칙',
#   '을',
#   '개정',
#   '저런',
#   '상황',
#   '다른',
#   '말로',
#   '다시',
#   '한번',
#   '기회',
#   '주다',
#   '야생마',
#   '같다',
#   '걸리다',
#   '저걸',
#   '분만',
#   '무슨',
#   '수로',
#   '길들이다'],
#  ['이건',
#   '경기',
#   '잘못',
#   '된거',
#   '같다',
#   '일본',
#   '측',
#   '에서',
#   '말',
#   '친해지다',
#   '시간',
#   '을',
#   '분만',
#   '주다',
#   '거도',
#   '이해',
#   '안',
#   '가다',
#   '차다',
#   '안타깝다'],
#  ['노력', '결과', '로', '채점', '되다', '아니다', '운빨', '맡기다', '되다', '종목', '왜', '있다'],
#  ['종목', '래서야', '없어지다', '맞다'],
#  ['올림픽', '창시자', '고안', '종목', '이며', '올림픽', '기', '원', '이기', '없어지다', '일', '없다'],
#  ['말', '갑자기', '저러다', '당근', '이라도', '비상', '용', '준비', '긴장', '이라도', '풀다'],
#  ['자기',
#   '애마',
#   '로',
#   '뛰다',
#   '연습',
#   '만',
#   '하고',
#   '길들이다',
#   '연습',
#   '안',
#   '했냨',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   'ㅋㅋㄹㅃㅃ'],
#  ['메달', '따다', '위해', '얼마나', '노력', '을', '보다', '내', '안타깝다', '미치다'],
#  ['농', '익다', '말', '이네'],
#  ['말', '얼마나', '똑똑하다', '복불복', '말', '아니다', 'ㅋ'],
#  ['스포츠',
#   '가위바위보',
#   '아니다',
#   '어떻',
#   '게',
#   '든',
#   '선수',
#   '피',
#   '땀',
#   '비례',
#   '결과',
#   '가다',
#   '나오다',
#   '국적',
#   '상관없다',
#   '관객',
#   '동의',
#   '겁니다'],
#  ['승마',
#   '인',
#   '으로써',
#   '공감',
#   '되다',
#   '부분',
#   '항상',
#   '자다',
#   '싶다',
#   '말',
#   '말',
#   '을',
#   '너무',
#   '안',
#   '을',
#   '때',
#   '있다',
#   '때',
#   '진짜',
#   '말',
#   '발',
#   '로',
#   '차다',
#   '다치다',
#   '때',
#   '보다',
#   '더',
#   '밉다',
#   '속상하다'],
#  ['원래',
#   '말',
#   '채찍',
#   '신나다',
#   '때리다',
#   '종목',
#   '아니다',
#   '카메라',
#   '있다',
#   '채찍',
#   '휘',
#   '두루',
#   '것',
#   '자제',
#   '건가'],
#  ['저', '말', '컨디션', '안', '좋다', '그렇다', '말', '힘들다'],
#  ['승마', '만', '빼다', '안되다'],
#  ['말',
#   '안',
#   '들다',
#   '입쪽',
#   '고삐',
#   '잡고',
#   'ㅈㄴ',
#   '째다',
#   '보다',
#   '채찍',
#   '질좀',
#   '해주다',
#   '함',
#   '초식동물',
#   '인',
#   '이상',
#   '기선',
#   '제압',
#   '필요'],
#  ['다음', '날', '말고기', '로', '전락'],
#  ['나중', '엔', '사족', '보행', '로봇', '대체', '되다', '듯'],
#  ['속상하다',
#   '알',
#   '지만',
#   '프로',
#   '선수',
#   '울다',
#   '별로',
#   '인',
#   '듯',
#   '이런',
#   '말',
#   '욕먹다',
#   '알',
#   '지만',
#   '말',
#   '결국',
#   '살다',
#   '존재',
#   '인거',
#   '고',
#   '싫다',
#   '울다',
#   '해결',
#   '되다',
#   '것',
#   '아니다',
#   '경기',
#   '중',
#   '울다',
#   '아니다',
#   '끝나다',
#   '아쉬움',
#   '을',
#   '표현',
#   '괜찮다',
#   '저',
#   '상황',
#   '말',
#   '에게',
#   '강요',
#   '걸',
#   '로',
#   '밖에',
#   '안',
#   '보이다',
#   '승마',
#   '해보다',
#   '알다',
#   '결국',
#   '말',
#   '교감',
#   '일텐데'],
#  ['저', '말', '도축', '말고기', '되다', '임'],
#  ['저런', '경기', '머', '룰', '두', '지다', '들다', '편하다'],
#  ['승마', '왜', '올림픽', '종목', '인지', '이해', '불가'],
#  ['운', '실력', '이다'],
#  ['올림픽', '계', '운빨', 'ㅈ', '망겜'],
#  ['이건',
#   '문제',
#   '있다',
#   '봄',
#   '실력',
#   '문제',
#   '아니다',
#   '순전하다',
#   '운',
#   '이니까',
#   '물론',
#   '말',
#   '교감',
#   '것',
#   '실력',
#   '라면',
#   '실력',
#   '이지만',
#   '말',
#   '에서',
#   '떨어지다',
#   '멈추다',
#   '거',
#   '보고',
#   '좋다',
#   '많이',
#   '그렇다'],
#  ['울다', '진짜', '꼴', '베다', '싫다', '울면', '뭐말', '미안하다', '잘해주다', '휴', '탈락', '이야'],
#  ['울면', '해결', '되다'],
#  ['자의', '로', '수', '있다', '것', '없다', '얼마나', '속상하다', 'ㅠ'],
#  ['치다', '존나', '보기', '싫다'],
#  ['어느',
#   '나라',
#   '말',
#   '이든',
#   '그나',
#   '라',
#   '언어',
#   '이쁘다',
#   '착하다',
#   '정도',
#   '만',
#   '미리',
#   '배우다',
#   '말',
#   '이랑',
#   '소통',
#   '도움',
#   '되다',
#   '듯',
#   '요'],
#  ['그냥', '자전거', '로', '바꾸다', '말', '불쌍하다'],
#  ['아니다', '자기', '말로', '뛰다', '아니다', 'ㄹㅇㅈ', '같다', '룰', '이네'],
#  ['말', '추첨', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['너무', '위험', '해보다', '이렇다', '규정', '개선', '되어다'],
#  ['약', '먹이다'],
#  ['우리',
#   '아버지',
#   '내',
#   '옆',
#   '에서',
#   '핸드폰',
#   '을',
#   '보고',
#   '있다',
#   '때',
#   '저',
#   '영상',
#   '을',
#   '같이',
#   '보고',
#   '있다',
#   '저',
#   '선수',
#   '최선',
#   '을',
#   '다',
#   '노력',
#   '감동',
#   '도쿄올림픽',
#   '나가다',
#   '선수',
#   '모두',
#   '수고'],
#  ['저',
#   '선수',
#   '딱하다',
#   '만은',
#   '원',
#   '치도',
#   '않다',
#   '채찍',
#   '주다',
#   '터지다',
#   '허들',
#   '넘다',
#   '말',
#   '더',
#   '딱하다'],
#  ['실제',
#   '전투',
#   '상황',
#   '라면',
#   '뺏다',
#   '타',
#   '보',
#   '니',
#   'ㅈ',
#   '같다',
#   '갖다',
#   '버리다',
#   '마리',
#   '더',
#   '뺏다',
#   '않다',
#   '적의',
#   '말',
#   '을',
#   '빼앗다',
#   '타다',
#   '설정',
#   '때문',
#   '라면',
#   '말',
#   '교체',
#   '권',
#   '을',
#   '한번',
#   '정도',
#   '주다',
#   '좋다',
#   '같다',
#   '말',
#   '도저히',
#   '안되다',
#   '겠다',
#   '바꾸다',
#   '게',
#   '여',
#   '한번',
#   '정도',
#   '바꾸다',
#   '찬스',
#   '주',
#   '는걸',
#   '로',
#   '바꾸다',
#   '되다'],
#  ['전쟁',
#   '중',
#   '내',
#   '길들이다',
#   '타고',
#   '다니다',
#   '말',
#   '아니다',
#   '적의',
#   '말',
#   '을',
#   '획득',
#   '타고',
#   '가다',
#   '설정',
#   '이라',
#   '무작위',
#   '로',
#   '말',
#   '을',
#   '타다',
#   '이해',
#   '가다',
#   '실력',
#   '보다는',
#   '내',
#   '추첨',
#   '말',
#   '말',
#   '을',
#   '자다',
#   '들다',
#   '안',
#   '들다',
#   '운',
#   '맡기다',
#   '진정하다',
#   '스포츠',
#   '정신',
#   '인지',
#   '다시',
#   '생각',
#   '해보다',
#   '야하다'],
#  ['경기',
#   '중',
#   '말',
#   '통제',
#   '되다',
#   '않다',
#   '빨리',
#   '내다',
#   '낙마',
#   '같다',
#   '사고',
#   '막다',
#   '않다',
#   '내리다',
#   '안되다',
#   '룰',
#   '이라도',
#   '있다',
#   '가요',
#   '말',
#   '싫어하다',
#   '의사',
#   '표현',
#   '듯',
#   '데',
#   '채찍',
#   '질',
#   '동물학대',
#   '아니다',
#   '동물',
#   '안타깝다',
#   '선수',
#   '안타깝다',
#   '뿐이다'],
#  ['운',
#   '때문',
#   '승부',
#   '갈리다',
#   '둘째',
#   '치고',
#   '잘못',
#   '선수',
#   '죽',
#   '을',
#   '수도',
#   '있다',
#   '규칙',
#   '을',
#   '바꾸다',
#   '않다',
#   '건',
#   '이해',
#   '가지',
#   '않다'],
#  ['거',
#   '뉴스',
#   '떳는데',
#   '선수',
#   '코치',
#   '랑',
#   '말',
#   '을',
#   '학대',
#   '문제',
#   '되다',
#   '있다',
#   '딱하다',
#   '안타깝다',
#   '않다'],
#  ['그냥',
#   '이렇게',
#   '영상',
#   '올리다',
#   '이유',
#   '없이',
#   '저러다',
#   '알',
#   '겠다',
#   '기전',
#   '말',
#   '때리다',
#   '말',
#   '때리다',
#   '패닉',
#   '오다',
#   '무슨',
#   '선수',
#   '만',
#   '안타깝다',
#   '마냥',
#   '말다',
#   '짐승',
#   '무슨',
#   '죕',
#   '니까',
#   '선수',
#   '운',
#   '없다',
#   '하지만',
#   '그렇다고',
#   '말',
#   '에게',
#   '폭력',
#   '행사',
#   '게',
#   '정당화',
#   '되다',
#   '않다'],
#  ['똥꼬', '올림픽'],
#  ['힘내다'],
#  ['근데', '스포츠', '머', '근', '희소성', '잇다'],
#  ['인간', '축제', '고생', '개', '처럼', '공감', '알다', '케어', '나서다', '주다', '좋다'],
#  ['말', '도살', '장', '갈다', 'ㅜㅜ'],
#  ['말', '아야', '하', '니깐', '싫다'],
#  ['웨이', '네', 'ㅋㅋㅋ'],
#  ['말', '럔덤', '복불복', 'ㅋㅋ', '운빨', '스포츠'],
#  ['말다', '듣다'],
#  ['오다', '마지막', '이승엽', '뭐', '냐'],
#  ['애초', '저', '게', '스포츠', '인가', '싶다'],
#  ['말', '안되다', '경기', '방식', '바꾸다', '당연하다'],
#  ['저', '거', '자세하다', '보다', '말', '웃음'],
#  ['게', '무슨', '말', '같다', '안다', '뽑다'],
#  ['저러다', '다시', '기회', '을', '주다', '되다', '보다', '비', '정상', '말', '이다'],
#  ['솔직하다',
#   '이렇다',
#   '영상',
#   '에선',
#   '그냥',
#   '응원',
#   '해주다',
#   '좋다',
#   '다욕',
#   '애',
#   '도대체',
#   '왜',
#   '그렇다',
#   '이해',
#   '안되다',
#   '선수',
#   '뭐',
#   '못',
#   '임',
#   '얼마나',
#   '안타깝다',
#   '상황',
#   '인데',
#   '수년',
#   '간',
#   '노력',
#   '무너지다',
#   '안타깝다',
#   '상황',
#   '인데'],
#  ['댓글', '달', '고우리', '아름답다', '올림픽', '원하다', '동참', '요'],
#  ['아니다',
#   '아프다',
#   '아니다',
#   '이상',
#   '없다',
#   '내다',
#   '체크',
#   '좋다',
#   '채찍',
#   '가지',
#   '고',
#   '엉',
#   '디',
#   '때리다',
#   '기만',
#   '하고',
#   '착착',
#   '소리',
#   '울음소리',
#   '랑',
#   '같이',
#   '들리다',
#   '안타깝다',
#   '말',
#   '불쌍하다'],
#  ['말', '다루다', '실력', '이다', '운', '다가', '아니다'],
#  ['방식',
#   '고치다',
#   '야하다',
#   '미리',
#   '미리',
#   '말',
#   '을',
#   '보내다',
#   '장기',
#   '준비',
#   '알다',
#   '기계',
#   '아니다',
#   '렌트',
#   '말',
#   '뭰말',
#   '이고',
#   '본국',
#   '말',
#   '이동',
#   '불가피하다',
#   '아니다',
#   '미리',
#   '미리',
#   '배정',
#   '말로',
#   '연습',
#   '준비',
#   '시스템',
#   '을',
#   '가다',
#   '너무',
#   'ㅠ',
#   '안타',
#   '갑',
#   '고',
#   '답답하다',
#   'ㅠㅠ'],
#  ['승마', '라는', '종목', '없어지다', '맞다', '아니다'],
#  ['구시대',
#   '종목',
#   '아직도',
#   '있다',
#   '놀',
#   '라울',
#   '뿐',
#   '명백하다',
#   '동물학대',
#   '임',
#   '그리고',
#   '저',
#   '울다',
#   '선수',
#   '코치',
#   '말',
#   '을',
#   '때리다',
#   '말',
#   '또한',
#   '스트레스',
#   '받다',
#   '말',
#   '을',
#   '안',
#   '들다',
#   '임',
#   '당연하다',
#   '퇴출됏',
#   '고',
#   '영상',
#   '수정',
#   '하',
#   '거나',
#   '정정',
#   '영상',
#   '올리다',
#   '같다'],
#  ['근데', '말', '저렇게', '말', '안', '듣다', '낙마', '안', '게', '다행', '이지'],
#  ['사람', '말', '말', '을', '못', '알다', '듣다', '위험하다', '싫다'],
#  ['말', '말', '을', '들다', '말', '안', '되다'],
#  ['저런',
#   '종목',
#   '인지',
#   '알',
#   '고',
#   '출전',
#   '거',
#   '아니다',
#   '저런',
#   '시',
#   '합방',
#   '식',
#   '싫다',
#   '누가',
#   '하래',
#   'ㅋㅋ'],
#  ['에구',
#   '안타깝다',
#   'ㅠㅠㅠㅠ',
#   '얼마나',
#   '속상하다',
#   'ㅠㅠㅠ',
#   '세상',
#   'ㅠㅠㅠ',
#   '말',
#   '진짜',
#   '위험하다',
#   '동물',
#   '인데',
#   '개선',
#   '꼭',
#   '필요하다'],
#  ['이건', '예전', '울', '나라', '선수', '말', '깔다', '사망', '함'],
#  ['선수',
#   '에게',
#   '허탈하다',
#   '줄',
#   '뿐',
#   '이다',
#   '저',
#   '경기',
#   '룰',
#   '만들다',
#   '사람',
#   '아',
#   '당신',
#   '많다',
#   '선수',
#   '메달',
#   '을',
#   '갈취'],
#  ['말고기', '로', '만들다', '버리다', '부다'],
#  ['말', '눈', '끄다', '리가', '돌아가다', '주먹질', '안', '생곃', '냐'],
#  ['아니다', '말', '을', '왜', '뽑기', '로', '정함', '승마', '처럼', '자다', '대다', '안되다'],
#  ['김유신', '장군', '저', '말', '을', '타다', '되다'],
#  ['내',
#   '말',
#   '이어도',
#   '무시',
#   '갑자기',
#   '처',
#   '타다',
#   '때리다',
#   'ㅈ',
#   '같다',
#   '말',
#   '안',
#   '듣다',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '더군다나',
#   '밟다',
#   '바로',
#   '죽다',
#   '약하다',
#   '생물'],
#  ['생물', '이런', '말', '보', '니깐', '흑염룡', '시기', '인가', '보다', 'ㅋㅋㅋ', '힘내다'],
#  ['그렇다',
#   'ㅈ',
#   '같다',
#   '느끼다',
#   '못',
#   '정도',
#   '로',
#   '거의',
#   '반',
#   '죽도로',
#   '패',
#   '서',
#   '움직이다',
#   '야하다'],
#  ['어떡하다', '진짜', '울다', '너무', '마음', '아프다', '진짜', '열심히', '준비', 'ㅠㅠㅠㅠㅠ'],
#  ['승마', '빼다', '낫다'],
#  ['말샠키', '표정', '겁나다', '얄밉다', 'ㅋㅋㅋ'],
#  ['평소', '당근', '을', '주다'],
#  ['평소',
#   '교감',
#   '시간',
#   '없다',
#   '첫',
#   '만남',
#   '채찍',
#   '뒤지다',
#   '직전',
#   '까지',
#   '후려',
#   '패',
#   '면',
#   '되다',
#   '근데',
#   '동물학대',
#   '라',
#   'ㅈㄹ',
#   '선수',
#   '입장',
#   '에선',
#   '운빨',
#   'ㅈ',
#   '망겜',
#   '되다',
#   '보다',
#   '입장',
#   '에서도',
#   '재미',
#   '없어지다'],
#  ['평소', '당근', '을', '줄', '기회', '없다', 'ㅠㅠ'],
#  ['걸',
#   '운',
#   '아니다',
#   '어쩔',
#   '수',
#   '없다',
#   '경기',
#   '특성',
#   '이다',
#   '말',
#   '과의',
#   '교감',
#   '을',
#   '못',
#   '라고',
#   '헛소리',
#   '애',
#   '심판',
#   '과의',
#   '교감',
#   '편파',
#   '판정',
#   '해도',
#   '인정',
#   '아니다'],
#  ['자다', '함께', '경기', '나가다', '좋다', 'ㅜㅜ'],
#  ['쿠베르탱', '못'],
#  ['아',
#   '짤',
#   '로',
#   '보다',
#   '땐',
#   '그냥',
#   '재밌다',
#   '일화',
#   '인',
#   '줄',
#   '알다',
#   '선수',
#   '생각',
#   '을',
#   '미치다',
#   '못',
#   '진짜',
#   '너무',
#   '속상하다'],
#  ['채찍', '후려', '갈겨', '버리다', '싶다', 'ㅋㅋ'],
#  ['천골', '마도', '방사능오염', '되다', '땅', '이라서', '놀래다', 'ㅠ'],
#  ['말', '던지다', 'ㅋㅋ', 'ㅅㄱ'],
#  ['추첨',
#   '을',
#   '통해',
#   '말',
#   '선정',
#   '되다',
#   '아니다',
#   '연습',
#   '때',
#   '부터',
#   '함께',
#   '해오다',
#   '말',
#   '맞다',
#   '아니다'],
#  ['스모', '선수', '모형', '말', '놀래다', '그렇다'],
#  ['게',
#   '노력',
#   '하고',
#   '상관없다',
#   '운빨',
#   '로',
#   '승부',
#   '되다',
#   '조련',
#   '능력',
#   '을',
#   '키우다',
#   '되다',
#   '건가'],
#  ['그날', '저녁', '말고기', '이다'],
#  ['게', '그', '운빨', '좆망', '겜', '이냐', '올림픽', '븅쉰같', '네', 'ㅎㅎ'],
#  ['도쿄올림픽',
#   '나오다',
#   '선수',
#   '분들',
#   '말',
#   '을',
#   '보내다',
#   '장애물',
#   '을',
#   '넘다',
#   '실력',
#   '이다',
#   '하지만',
#   '몇',
#   '년',
#   '간',
#   '힘들다',
#   '노력',
#   '올림픽',
#   '오다',
#   '운',
#   '맞다',
#   '겨',
#   '안타깝다',
#   'ㅠ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋ', '말', '쉨', 'ㅋㅋㅋㅋ', '골', '때리다', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['말', '말', '을', '듣다', '않다'],
#  ['말', '불쌍하다', '개인', '이득', '을', '위해', '말', '엉덩이', '맞다', '싫다', '행동', '을'],
#  ['승마',
#   '등',
#   '말',
#   '선수',
#   '함께',
#   '경기',
#   '말',
#   '능력',
#   '능력',
#   '이지만',
#   '선수',
#   '말',
#   '서로',
#   '파트너쉽',
#   '기본',
#   '되다',
#   '경기',
#   '라고',
#   '생각',
#   '승마',
#   '선수',
#   '평소',
#   '말',
#   '교감',
#   '하고',
#   '좋다',
#   '걸',
#   '먹이',
#   '고',
#   '함께',
#   '경기',
#   '뛰다',
#   '파트너',
#   '로서',
#   '존중',
#   '하고',
#   '감사하다',
#   '표현',
#   '건',
#   '함께',
#   '오랜',
#   '시간',
#   '에서',
#   '나오다',
#   '것일',
#   '것',
#   '같다',
#   '하지만',
#   '영상',
#   '경기',
#   '말',
#   '스트레스',
#   '받다',
#   '수',
#   '밖에',
#   '없다',
#   '단지',
#   '말',
#   '경기',
#   '위',
#   '도구로',
#   '밖에',
#   '보이지',
#   '않다',
#   'ㅠㅠ',
#   '지금',
#   '근대',
#   '아니다',
#   '현대',
#   '이니',
#   '만큼',
#   '좋다',
#   '방향',
#   '개선',
#   '되어다',
#   '좋다'],
#  ['말', '이상하다', '야생마', '같다'],
#  ['말고기', '마렵다'],
#  ['말', '말', '을', '안', '듣다', 'ㅋㅋㅋ'],
#  ['안타깝다', '움', '남', '상황', '보이지', '않다', '요다음', '또', '기회', '있다', '겁니다', '화이팅'],
#  ['아', '너무', '슬프다', '울다', '보다', 'ㅠㅠ', '힘내다'],
#  ['선수', '선수', '지만', '나', '왜', '이렇게', '말', '더', '불쌍하다', '안타깝다', 'ㅠㅠ'],
#  ['물장구',
#   'ㅋㅋ',
#   '님',
#   '같다',
#   '사람',
#   '때문',
#   '이렇다',
#   '스포츠',
#   '재미',
#   '없어지다',
#   '솔직하다',
#   '저런',
#   '상황',
#   '에서',
#   '채찍',
#   '질',
#   '로',
#   '후',
#   '겨',
#   '갈겨',
#   '서다',
#   '말',
#   '정상',
#   '작동',
#   '메달',
#   '딴다',
#   '얼마나',
#   '자극',
#   '적',
#   '이고',
#   '훌륭하다',
#   '전',
#   '개입',
#   '니까',
#   '사실',
#   '상',
#   '니',
#   '같다',
#   '사람',
#   '선수',
#   '메달',
#   '뺏다',
#   '마찬가지',
#   '임'],
#  ['거',
#   '완전',
#   '미치다',
#   '갱',
#   '아니다',
#   '말',
#   '경기',
#   '하고',
#   '싶다',
#   '대다',
#   '동물',
#   '인간',
#   '을',
#   '위해',
#   '희생',
#   '해주다',
#   '치다',
#   '맞다',
#   '모',
#   '자르다',
#   '님인듯'],
#  ['ㅋㅋ',
#   '저',
#   '상황',
#   '뒤지다',
#   '직전',
#   '까지',
#   '치다',
#   '맞다',
#   '모자라다',
#   '판',
#   '말',
#   '불쌍하다',
#   'ㅋㅋ',
#   '어이',
#   '없다'],
#  ['짧다', '시간'],
#  ['명색', '승마', '인데', '자다', '쓸다', '없다', '차다', 'ㅜ'],
#  ['내', '말', '였음', '참수'],
#  ['말',
#   '과의',
#   '교감',
#   '중요하다',
#   '하지만',
#   '이건',
#   '좀룰',
#   '을',
#   '바꾸다',
#   '야하다',
#   '않다',
#   '선수',
#   '말',
#   '다',
#   '스트레스',
#   '받다'],
#  ['싸이클', '로', '바꾸다', '나다'],
#  ['울다',
#   '말',
#   '을',
#   '진정',
#   '시키다',
#   '교감',
#   '후',
#   '출발',
#   '어떻다',
#   '말다',
#   '울',
#   '고',
#   '잇다',
#   '불안하다',
#   '말',
#   '자다',
#   '못',
#   '안',
#   '타다',
#   '가다'],
#  ['저', '종목', '말타', '거만', '빼다', '안되다', '너무', '운빨', '이네', '뽑기', '잘못', '망하다'],
#  ['전쟁',
#   '중',
#   '적군',
#   '말',
#   '을',
#   '빼다',
#   '타다',
#   '유래',
#   '되다',
#   '종목',
#   '이다',
#   '아무래도',
#   '적군',
#   '말',
#   '수년',
#   '동안',
#   '교감',
#   '어렵다'],
#  ['빨리', '개선', '해', '라'],
#  ['낙마', '개', '위험하다', '아니다', '같다'],
#  ['김유신', '장군', '말', '을', '칼', '로', '찌르다', '죽이다', '이유', '이다'],
#  ['왠지',
#   '훌륭하다',
#   '선수',
#   '이다',
#   '같다',
#   '경기',
#   '끝나다',
#   '말',
#   '에게',
#   '미안하다',
#   '같다',
#   '더',
#   '슬픔'],
#  ['ㅈㄴ', '억울하다', 'ㄹㅇ', '보다', '내', '다', '안타깝다', 'ㅉㅉ'],
#  ['말',
#   '컨디션',
#   '까지',
#   '보다',
#   '내',
#   '노력',
#   '아니다',
#   '말',
#   '노력',
#   '까지',
#   '필요하다',
#   '너무',
#   '어렵다',
#   '종목',
#   '이다'],
#  ['시대',
#   '변하다',
#   '동물',
#   '을',
#   '집어넣다',
#   '종목',
#   '고려',
#   '되다',
#   '안닌',
#   '사람',
#   '에게도',
#   '말',
#   '에게도',
#   '다른',
#   '종목',
#   '대체',
#   '되다'],
#  ['원래', '승마', '말', '거의', '다', '거지'],
#  ['운', '실력', '이란', '게', '스포츠', '에도', '적용', '되다', '순간', '이네', '요'],
#  ['말',
#   '상태',
#   '따르다',
#   '결정',
#   '되다',
#   '실력',
#   '라이',
#   '종목',
#   '없애다',
#   '라이',
#   '게',
#   '무슨',
#   '실력',
#   '이냐'],
#  ['말',
#   '힘들다',
#   '수도',
#   '힘들다',
#   '보다',
#   '사람',
#   '마음',
#   '힘드다',
#   '경기',
#   '이다',
#   '말',
#   '아',
#   '너',
#   '최선',
#   '을',
#   '다해',
#   '주다',
#   '푹',
#   '쉬다'],
#  ['좋다',
#   '의견',
#   '감사하다',
#   '하지만',
#   '제',
#   '경기',
#   '볼때',
#   '말',
#   '장애물',
#   '을',
#   '최대한',
#   '넘다',
#   '힘',
#   '을',
#   '써다',
#   '모습',
#   '답글',
#   '을',
#   '달',
#   '아',
#   '보다',
#   '그렇다'],
#  ['말',
#   '최선',
#   '을',
#   '다',
#   '생각',
#   '하',
#   '군',
#   '요',
#   '저',
#   '그렇다',
#   '않다',
#   '물론',
#   '말',
#   '컨디션',
#   '따르다',
#   '경기',
#   '승패',
#   '달리다',
#   '거',
#   '라고',
#   '하지만',
#   '저',
#   '말',
#   '을',
#   '케어',
#   '못',
#   '올림픽',
#   '측',
#   '지다',
#   '있다',
#   '생각'],
#  ['동물학대', '올림픽', '이라는', '이유', '로', '말', '학대', '당하다', '있다'],
#  ['자다', '아니다', '추점', '제라', '구', '요', '말', '오지', '게', '예민하다', '동물', '아니다'],
#  ['교감',
#   '안되다',
#   '너무',
#   '위험하다',
#   '다행',
#   '인',
#   '건',
#   '말',
#   '사람',
#   '을',
#   '떨어뜨리다',
#   '안',
#   '개선'],
#  ['ㅜㅜ', '으', '맘', '아프다', '진짜'],
#  ['말고기', '로', '담그다'],
#  ['분동',
#   '안',
#   '말',
#   '이랑',
#   '친해지다',
#   '교감',
#   '시간',
#   '주어지다',
#   '저',
#   '독일',
#   '선수',
#   '랑',
#   '코치',
#   '길들이다',
#   '말',
#   '을',
#   '때리다',
#   '밝혀지다',
#   '나찌',
#   '코치',
#   '자격',
#   '박탈',
#   '당하다',
#   '개사',
#   '이다',
#   '말',
#   '아'],
#  ['엄승현', '네'],
#  ['포털', '말', '때리다', '퇴', '추다', '이라고', '치다', '보다'],
#  ['진짜', '인가요'],
#  ['오다',
#   '우리나라',
#   '선수',
#   '낙마',
#   '영상',
#   '보',
#   '니까',
#   '아찔하다',
#   '낙마',
#   '잘못',
#   '불구',
#   '라도',
#   '되다',
#   '에서',
#   '책임지다',
#   '줄',
#   '건가'],
#  ['유감',
#   '이지만',
#   '어쩔',
#   '수',
#   '없다',
#   '룰',
#   '나중',
#   '바뀌다',
#   '운',
#   '이라고',
#   '해도',
#   '경기',
#   '중',
#   '일',
#   '부임',
#   '선수',
#   '충분하다',
#   '인지',
#   '터',
#   '이고',
#   '만약',
#   '자기',
#   '보다',
#   '높다',
#   '점수',
#   '선수',
#   '운',
#   '나쁘다',
#   '저런',
#   '상황',
#   '생기다',
#   '유감',
#   '을',
#   '표',
#   '하',
#   '되다',
#   '누구',
#   '보다',
#   '악착같이',
#   '역전',
#   '을',
#   '노리다',
#   '선수',
#   '들이다',
#   '다만',
#   '자신',
#   '운',
#   '안좋다',
#   '저렇게',
#   '돼다',
#   '뿐'],
#  ['뽑다', '좋다', '이기다', '무슨', '스포츠', '임', '도박', '이지'],
#  ['낙마', '진짜', '아프다', 'ㅠ'],
#  ['낙마', '밣히', '면', '죽다', '죽', '을', '각오', '오다', '울다'],
#  ['진짜', '미개하다', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['운', '실력', '이다', '결국', '되다', '놈', '되다', '세상'],
#  ['말', '새끼', '왜', '저렇다', '더위', '처', '먹다', 'ㅡㅡ', '시발'],
#  ['분만', '멀다', '교감', '을', '해', 'ㅋㅋㅋ', '개', '운빨', '겜', '이네'],
#  ['원래', '취지', '라면', '다', '같이', '처음', '보다', '말로', '교감', '없이', '타다', '맞다'],
#  ['종목',
#   '무지하다',
#   '그렇다',
#   '그',
#   '전',
#   '에도',
#   '랜덤',
#   '배정',
#   '경기',
#   '인가요',
#   '일반인',
#   '이라',
#   '이해',
#   '못',
#   '승마',
#   '목숨',
#   '위험하다',
#   '직종',
#   '이라고',
#   '알다',
#   '위험',
#   '해보다'],
#  ['개', '빡치다', 'ㅠㅠ'],
#  ['말', '힘들다', '사람', '힘드다', '저런', '말', '너무', '예민하다', '그렇다'],
#  ['말', '인간', '에게', '최고', '복수', '아니다'],
#  ['승마',
#   '같다',
#   '종목',
#   '파트너',
#   '호흡',
#   '중요하다',
#   '처음',
#   '만난',
#   '말',
#   '이랑',
#   '같이',
#   '뛰다',
#   '되다',
#   '나',
#   '이해',
#   '안감'],
#  ['자다', '데려오다', '저건', '진짜', '아니다'],
#  ['운',
#   '실력',
#   '이라는',
#   '건',
#   '뭐',
#   '사람',
#   '이지운',
#   '자기',
#   '맘대로',
#   '되다',
#   '막상',
#   '자기',
#   '운',
#   '없다',
#   '일',
#   '꼬이다',
#   '때',
#   '운',
#   '실력',
#   '이란',
#   '말',
#   '들다',
#   '급발진',
#   'ㅋㅋㅋ'],
#  ['무작위', '로', '말', '을', '뽑다', '버리다', '지면', '저', '사람', '얼마나', '억울'],
#  ['개', '어이없다', 'ㅋㅋㅋㅋㅋ'],
#  ['그게', '목적', '이래', '요', '모르다', '말', '친해지다', '이기', '고', '싶다', '친해지다'],
#  ['동물',
#   '과의',
#   '교감',
#   '능력',
#   '보다',
#   '경기',
#   '전쟁',
#   '에서',
#   '적의',
#   '말',
#   '을',
#   '빼앗다',
#   '타다',
#   '설정',
#   '있다',
#   '함'],
#  ['ㅠㅠㅠㅠㅠㅠㅠㅠㅠ', '내', '다', '안타깝다', 'ㅠㅠㅠㅠㅠㅠㅠ', '하이', '구', 'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['오다',
#   '거',
#   '반전',
#   '반전',
#   '이네',
#   '저',
#   '말',
#   '이전',
#   '에도',
#   '달리다',
#   '것',
#   '을',
#   '거부',
#   '모두',
#   '알',
#   '고',
#   '있다',
#   '선수',
#   '코치',
#   '말',
#   '건드리다',
#   '경기',
#   '개입',
#   '올림픽',
#   '에서',
#   '퇴',
#   '추다',
#   '당하다',
#   '선수',
#   '말',
#   '안',
#   '듣다',
#   '채찍',
#   '치다',
#   '울면',
#   '서',
#   '온갖',
#   '짓',
#   '을',
#   '비난',
#   '쏟아지다',
#   '있다',
#   '추가',
#   '징계',
#   '기다리다',
#   '있다',
#   '종목',
#   '목적',
#   '말',
#   '교감',
#   '을',
#   '능력',
#   '을',
#   '측정',
#   '것',
#   '인데',
#   '동물',
#   '학대',
#   '모습',
#   '을',
#   '보이다',
#   '뭐',
#   '이르다',
#   '오다',
#   '예상',
#   '밖',
#   '인데',
#   '요'],
#  ['이렇다',
#   '운발',
#   '게임',
#   '을',
#   '아직도',
#   '스포츠',
#   '랍시고',
#   '올림픽',
#   '나오다',
#   '차라리',
#   '병림픽',
#   '이라'],
#  ['년',
#   '태어나다',
#   '년',
#   '죽다',
#   '쿠베르탱',
#   '만들다',
#   '운동',
#   '년',
#   '맞다',
#   '생각',
#   '그사세',
#   '네',
#   '제일',
#   '문제',
#   '뭐',
#   '냐',
#   '면',
#   '종목',
#   '선택',
#   '연습',
#   '하고',
#   '출전',
#   '선수',
#   '들이다',
#   '다',
#   '같이',
#   '보이콧',
#   '저런',
#   '종목',
#   '없어지다'],
#  ['아니다', '너무', '안타깝다', '무슨', '말', '을', '추첨'],
#  ['근데', '위험하다', '않다', 'ㅠ', '선수', '다치다'],
#  ['자신',
#   '말로',
#   '경기',
#   '누구',
#   '죽이다',
#   '이렇다',
#   '위험하다',
#   '경기',
#   '건지다',
#   '모르다',
#   '진짜',
#   '누구',
#   '죽다',
#   '어쩔',
#   '려고',
#   '운영',
#   '능력',
#   '안되다',
#   '경기',
#   '내용',
#   '을',
#   '바꾸다'],
#  ['저', '거', '보다', '낙마', '위험성', '너무', '높다', '무게', '상당하다', '깔리다', '밟다', 'ㄷㄷ'],
#  ['말', '에게도', '분명', '이유', '있다', '무엇', '이다', '몸', '상태', '좋다', '않다', '걸다', 'ㅠㅠ'],
#  ['뒤지다',
#   '직전',
#   '까지',
#   '후려',
#   '패',
#   '야',
#   '말',
#   '을',
#   '들다',
#   '동물',
#   '협회',
#   '니',
#   '뭐',
#   '니',
#   '이딴',
#   '것',
#   '채찍',
#   '질',
#   '못',
#   '막다',
#   '팔자',
#   '좋다',
#   '난리',
#   '피우다',
#   'ㅋㅋ'],
#  ['말', '말', '을', '안', '듣다'],
#  ['박수', '받다', '마땅하다', '얼마나', '속상하다', 'ㅠ'],
#  ['아이고', '고생', '많다'],
#  ['운빨', '좆망', '겜', 'ㅋㅋㅋ'],
#  ['너무하다', '올림픽', '허다', '술', '하', '다'],
#  ['차라리',
#   '허슬',
#   '로',
#   '바꾸다',
#   '사람',
#   '넘다',
#   '왜',
#   '말',
#   '넘다',
#   '아니다',
#   '말',
#   '하고',
#   '친해지다',
#   '시간',
#   '을',
#   '미리',
#   '주다',
#   '뭔',
#   '잘못',
#   '이고',
#   '저',
#   '사람',
#   '뭔',
#   '잘못',
#   '인지',
#   '하지만',
#   '그렇다고',
#   '동물',
#   '을',
#   '다중',
#   '개',
#   '되다',
#   '말',
#   '을',
#   '때리다',
#   '세다',
#   '때리다',
#   '아니다',
#   '안되다',
#   '일임'],
#  ['방식',
#   '을',
#   '어느',
#   '정도',
#   '개선',
#   '필요',
#   '있다',
#   '보이다',
#   '랜덤',
#   '을',
#   '없애다',
#   '랜덤',
#   '배정',
#   '되다',
#   '말',
#   '교감',
#   '시간',
#   '을',
#   '최소',
#   '하루',
#   '정도',
#   '로',
#   '길다',
#   '주다',
#   '식',
#   '요',
#   '매번',
#   '이런',
#   '식인',
#   '건',
#   '몇',
#   '년',
#   '간',
#   '고생',
#   '선수',
#   '에게',
#   '너무',
#   '가혹하다',
#   '같다'],
#  ['눈물나다'],
#  ['승마',
#   '대체',
#   '누굴',
#   '위',
#   '종목',
#   '인가',
#   '골프',
#   '그렇지만',
#   '도대체',
#   '서민',
#   '근처',
#   '가보다',
#   '힘드다',
#   '부유하다',
#   '취미',
#   '거리',
#   '왜',
#   '신성하다',
#   '올림픽',
#   '종목',
#   '에까지',
#   '올리다',
#   '건지다',
#   '납득',
#   '없다',
#   '사격',
#   '이나',
#   '양궁',
#   '딱하다',
# ...
#  ['너무',
#   '시대',
#   '뒤',
#   '떨어지다',
#   '공평',
#   '성',
#   '보장',
#   '되다',
#   '않다',
#   '종목',
#   '아니다',
#   '아무리',
#   '말',
#   '교감',
#   '실력',
#   '이르다',
#   '과연',
#   '게',
#   '공정하다',
#   '룰',
#   '인지'],
#  ['보다', '나다', '눈물', '나다', 'ㅠㅠ'],
#  ['말', '지진', '을', '감지', '햇', '다'],
#  ['나다',
#   '저',
#   '기분',
#   '알',
#   '지',
#   '내',
#   '아무리',
#   '노력',
#   '운',
#   '안되다',
#   '현실',
#   '진짜',
#   '기분',
#   'ㅈ',
#   '같다'],
#  ['이제', '말', '을', '못패', '니', '지다', '들다', '타다', '말로'],
#  ['개패듯패', '야하다', '저러다'],
#  ['사람', '말', '을', '듣다', '않다', '개패', '듯이', '페야', '죠'],
#  ['아무리',
#   '적의',
#   '말',
#   '뺏다',
#   '컨셉',
#   '이라',
#   '일주일',
#   '정돈',
#   '교감',
#   '시간',
#   '주다',
#   '야하다',
#   '않다',
#   'ㅠ',
#   '선수',
#   '말',
#   '에게도',
#   '너무',
#   '스트레스',
#   '이다',
#   '낙마',
#   '보',
#   '니깐',
#   '너무',
#   '위험',
#   '해보다'],
#  ['진짜',
#   'ㅂ',
#   '신',
#   '같다',
#   '전통',
#   '지키다',
#   '기본',
#   '적',
#   '경쟁',
#   '수',
#   '있다',
#   '상황',
#   '을',
#   '만들다',
#   'ㅋㅋ',
#   '개',
#   '말',
#   '안되다',
#   '논리',
#   '펼치다',
#   '년'],
#  ['말',
#   '엄청',
#   '스트레스',
#   '받다',
#   '그렇다',
#   '던데',
#   '시대',
#   '맞추다',
#   '대책',
#   '필요하다',
#   '것',
#   '같다',
#   '선수',
#   '에게도',
#   '말',
#   '에게도',
#   '경기',
#   '력',
#   '상관',
#   '없다',
#   '시대',
#   '뒤',
#   '떨어지다',
#   '룰',
#   '바꾸다',
#   '야하다',
#   '필요',
#   '있다',
#   '것',
#   '같다',
#   '아무리',
#   '전장',
#   '에서',
#   '말',
#   '을',
#   '뺏다',
#   '타다',
#   '것',
#   '에서',
#   '유래',
#   '되어다',
#   '말',
#   '을',
#   '학대',
#   '것임',
#   '동시',
#   '선수',
#   '에게도',
#   '부상',
#   '위험',
#   '너무',
#   '크다',
#   '종목',
#   '인데',
#   '룰',
#   '을',
#   '수정',
#   '것',
#   '정도',
#   '충분하다',
#   '조치',
#   '수',
#   '있다',
#   '것',
#   '아니다',
#   '싶다'],
#  ['저', '게', '왜', '학대', '임'],
#  ['속상하다',
#   '경기',
#   '분전',
#   '만나다',
#   '교감',
#   '한다는',
#   '게',
#   '쉬다',
#   '않다',
#   '말',
#   '경기',
#   '빼다',
#   '좋다',
#   '듯'],
#  ['저', '누무', '말샠', 'ㄱ'],
#  ['너무', '안타깝다'],
#  ['승마',
#   '동물학대',
#   '다',
#   '올림픽',
#   '종목',
#   '에서',
#   '없어지다',
#   '개',
#   '고양이',
#   '돌고래',
#   '길들이다',
#   '학대',
#   '이고',
#   '말',
#   '학대',
#   '아니다',
#   '공',
#   '정치',
#   '못',
#   '물어',
#   '보다',
#   '흑인',
#   '을',
#   '잡다',
#   '노예',
#   '로',
#   '만들다',
#   '뭣',
#   '다르다',
#   '동물',
#   '로서',
#   '자유',
#   '주다',
#   '씨발'],
#  ['경',
#   '기',
#   '규정',
#   '을',
#   '바꾸다',
#   '필요',
#   '있다',
#   '보이다',
#   '저',
#   '게',
#   '스포츠',
#   '냐',
#   '올림픽',
#   '위원',
#   '대체',
#   '뭐',
#   '거',
#   '냐',
#   '사람',
#   '쥭',
#   '이겠다'],
#  ['그', '와중', '말', '이름', '세인트', '보이', '네'],
#  ['오지',
#   '랍',
#   '보다',
#   '인성',
#   '쓰레기',
#   '바',
#   '닦다',
#   '쓰레기',
#   '다',
#   '버리다',
#   '못',
#   '되다',
#   '처',
#   '먹다',
#   '것',
#   '이렇다',
#   '보다',
#   '가식',
#   '뜨다',
#   '역겹다'],
#  ['마치', '한국', '지금', '상황', '똑같다'],
#  ['채찍마렵', '네', 'ㅋㅋ'],
#  [],
#  ['안타깝다', 'ㅜㅜ', '울음소리', '넘다', '넘다', '슬프다'],
#  ['처음',
#   '만난',
#   '말',
#   '단번',
#   '교감',
#   '숫말',
#   '냄새',
#   '암',
#   '말',
#   '냄새',
#   '묻히다',
#   '옷',
#   '을',
#   '준비',
#   '배정',
#   '되다',
#   '말',
#   '성별',
#   '맞추다',
#   '입다',
#   '되다'],
#  ['승부', '운', '맡기다'],
#  ['언럭키', '고', '루시'],
#  ['말고기', '해먹', '어', 'ㅇㅈ', '인부', '분'],
#  ['짐승', '따위', '때문', '인간', '우', '네', '저', '종목', '빼다'],
#  ['일본', '이라는', '글자', '지나다', '일본', '이라는', '글자', '놀래다'],
#  ['울다',
#   '알다',
#   '말',
#   '을',
#   '너무',
#   '쌔',
#   '게',
#   '후려치다',
#   '같다',
#   '그게',
#   '왜',
#   '다독이다',
#   '건지다',
#   '수정',
#   '찾아보다',
#   '해당',
#   '선수',
#   '말',
#   '을',
#   '때리다',
#   '올림픽',
#   '퇴',
#   '추다',
#   '당하다',
#   '징계',
#   '까지',
#   '먹다',
#   '이딴',
#   '뉴스',
#   '만들다',
#   '이유',
#   '뭡',
#   '니까'],
#  ['말', '스트레스', '엄청', '받다', '같다'],
#  ['장애물', '진짜', '개떡같다', '저러다', '말', '겁', '을', '먹다'],
#  ['러시아',
#   '나',
#   '중국',
#   '말다',
#   '저녁',
#   '반찬',
#   '말고기',
#   '다',
#   '열심히',
#   '연습',
#   '왜',
#   '속상하다',
#   '그렇다',
#   '그래도',
#   '끝',
#   '까지',
#   '열심히',
#   '것',
#   '대단하다',
#   '생각'],
#  ['웃기다',
#   '우리나라',
#   '메달',
#   '따다',
#   '중계',
#   '안',
#   '해주다',
#   '선수',
#   '더',
#   '불쌍하다',
#   '얼마나',
#   '중계',
#   '안해',
#   '주다',
#   '중계',
#   '해주다',
#   '해설',
#   '울다'],
#  ['혹시',
#   '말',
#   '한테',
#   '오늘',
#   '컨디션',
#   '괜찮다',
#   '오늘',
#   '뛰다',
#   '수',
#   '있다',
#   '물어',
#   '보고',
#   '경기',
#   '내보내다',
#   '임'],
#  ['휴', '맘', '아프다'],
#  ['온순하다', '말', '듣다', '애', '로', '준비', '해주다', '저러다', '선수', '만', '손해', '알다', 'ㅠ'],
#  ['년',
#   '말',
#   '에서',
#   '떨어지다',
#   '우리',
#   '선수',
#   '이번',
#   '독일',
#   '선수',
#   '마음',
#   '아프다',
#   'ㅠ',
#   '특히',
#   '말',
#   '아예',
#   '멈추다',
#   '진짜',
#   '멘탈',
#   '나가다',
#   '수',
#   '밖에',
#   '없다',
#   'ㅠ',
#   '말',
#   '말',
#   '대로',
#   '스트레스',
#   '받다',
#   '사람',
#   '스트레그',
#   '받다',
#   '속상하다',
#   '상황',
#   '이네',
#   '요',
#   '정말'],
#  ['자기', '원하다', '말', '이나', '훈련', '같다', '말', '쓰다', '가장', '공정하다', '보다'],
#  ['너무', '흑', '흑', '울다', 'ㅋㅋㅋ'],
#  ['경기', '보다', '눈물', '앞', '을', '가리다', 'ㅠㅠ'],
#  ['게', '종목', '인가', 'ㅉㅉ', 'ㅂㅅ', '같다', '종목'],
#  ['정말',
#   '열심히',
#   '준비',
#   '하고',
#   '자신',
#   '있다',
#   '일이',
#   '내',
#   '뜻대로',
#   '되다',
#   '않다',
#   '때',
#   '정말',
#   '속상하다',
#   '저',
#   '선수',
#   '입장',
#   '을',
#   '완전하다',
#   '이해',
#   '못',
#   '어느',
#   '정도',
#   '공감',
#   '간다',
#   'ㅠㅠ',
#   '저',
#   '날',
#   '을',
#   '위해',
#   '몇',
#   '달',
#   '며칠',
#   '을',
#   '갈고',
#   '닦다',
#   '오다',
#   '텐데',
#   'ㅠㅠㅠㅠ'],
#  ['말다'],
#  ['조형', '물', '한몫', '곳', '같다', '낯선', '경기장'],
#  ['잡아먹다'],
#  ['물', '올리다', '요'],
#  ['차다',
#   '규정',
#   'ㅂㅅ',
#   '같다',
#   '다른',
#   '종목',
#   '처럼',
#   '자기',
#   '장비',
#   '가져오다',
#   '쓰다',
#   '종목',
#   '자신',
#   '타다',
#   '말',
#   '가져오다',
#   '쓰다',
#   '되다'],
#  ['말', '불쌍하다', '선수', '불쌍하다', '휴'],
#  ['전쟁',
#   '이라는',
#   '설정',
#   '이기다',
#   '해도',
#   '스포츠',
#   '스포츠',
#   '대로',
#   '개선',
#   '하고',
#   '진행',
#   '생각',
#   '함',
#   '전쟁',
#   '잔인하다',
#   '비',
#   '평화',
#   '적',
#   '인데',
#   '설정',
#   '이라고',
#   '스포츠',
#   '그대로',
#   '적용',
#   '순',
#   '없다',
#   '저',
#   '정도',
#   '로',
#   '다루다',
#   '모든',
#   '말',
#   '다',
#   '듣기',
#   '엔',
#   '무리',
#   '있다',
#   '생각',
#   '함',
#   '근데',
#   '저',
#   '정도',
#   '이상',
#   '다루다',
#   '폭력',
#   '학대',
#   '라는',
#   '문제',
#   '생기다',
#   '규칙',
#   '을',
#   '개선',
#   '게',
#   '맞다',
#   '듯'],
#  ['댓글', '짐승', '새끼', 'ㅂㄷ', '거리', '노', 'ㅋ'],
#  ['식', 'ㄹㅇㅋㅋ'],
#  ['식',
#   '저',
#   '선수',
#   '분',
#   '공감',
#   '못',
#   '보다',
#   '사이코',
#   '맞다',
#   '뭐',
#   'ㅋ',
#   '그리고',
#   '지다',
#   '행동',
#   '기억',
#   '못',
#   '분',
#   '이랑',
#   '대화',
#   '싫다',
#   'ㅋㅋ',
#   '평생',
#   '그렇다',
#   '살다'],
#  ['알다', '언니', '뭔', '답글', '을', '삭제', '그리고', '차피', '난', '저', '선수', '아니다', 'ㅋ'],
#  ['답글', '까지', '삭제', '거보', '니까', '잘못', '인지', '보다'],
#  ['화려하다', '장', '식물', '때문', '인', '영향', '있다', '않다', '안타깝다'],
#  ['양자역학',
#   '부합',
#   '되다',
#   '종목',
#   '이네',
#   '거기',
#   '선',
#   '절대',
#   '불변',
#   '확실하다',
#   '정해진',
#   '건',
#   '없다',
#   '복불복',
#   '확률',
#   '게임',
#   '이여'],
#  ['솥', '물', '끓이다'],
#  ['ㅎㅎ'],
#  ['말쉑', '표정', '보다', 'ㅋㅋㅋㅋ', '육포마렵', '네'],
#  ['말', '표정', '보다', '사람', '멕', '중'],
#  ['그렇다고', '말', '을', '주먹', '치면', '쓰다'],
#  ['내',
#   '생각',
#   '아무리',
#   '보다',
#   '말',
#   '달래다',
#   '실력',
#   '같다',
#   '설정',
#   '긴급하다',
#   '상황',
#   '적',
#   '에게',
#   '뺏다',
#   '무작위',
#   '말',
#   '이고',
#   '말위',
#   '에서',
#   '저렇게',
#   '울다',
#   '말',
#   '달래다'],
#  ['옛날', '에는', '주다', '패', '서', '달래다', '요즘', '엔', '그렇다', '난리', '나서다', 'ㅋㅋㅋㅋ'],
#  ['운빨겜', '이구만', 'ㅋㅋㅋㅋ'],
#  ['그렇게', '전쟁', '상황', '중시', '사람', '뛰다', '되다', 'ㅋㅋㅋ'],
#  ['홀스', '스톤', 'ㅋㅋ'],
#  ['다',
#   '떠나다',
#   '교감',
#   '안되다',
#   '말',
#   '을',
#   '타라',
#   '거',
#   '자체',
#   '너무',
#   '위험하다',
#   '기존',
#   '스포츠',
#   '창설',
#   '당시',
#   '설정',
#   '특징',
#   '만',
#   '따다',
#   '그대로',
#   '펜싱',
#   '이건',
#   '태권도',
#   '건',
#   '룰',
#   '개정',
#   '필요',
#   '없다'],
#  ['그',
#   '모든',
#   '과정',
#   '을',
#   '분',
#   '만에',
#   '해내다',
#   '한다는',
#   '게',
#   '너무',
#   '빡센것',
#   '같다',
#   '안',
#   '그렇다',
#   '예민하다',
#   '겁',
#   '많다',
#   '동물',
#   '을'],
#  ['사람',
#   '교감',
#   '이라는',
#   '단어',
#   '써다',
#   '오해',
#   '많이',
#   '살다',
#   '따뜻하다',
#   '기수',
#   '리더',
#   '아니다',
#   '말',
#   '두려움',
#   '을',
#   '받다',
#   '강인하다',
#   '이끌다',
#   '리더',
#   '교감',
#   '리더',
#   '라고',
#   '말',
#   '진짜',
#   '겁',
#   '많다',
#   '동물',
#   '임'],
#  ['교감',
#   '되다',
#   '말',
#   '말',
#   '을',
#   '자다',
#   '듣다',
#   '거',
#   '아니다',
#   '매일',
#   '타다',
#   '말',
#   '저런',
#   '날',
#   '많다',
#   '글',
#   '고',
#   '저러다',
#   '때',
#   '저렇게',
#   '말위',
#   '에서',
#   '계속',
#   '박차',
#   '채찍',
#   '지다',
#   '교관',
#   '보다',
#   '적',
#   '없다',
#   '그리고',
#   '저런',
#   '상황',
#   '에서',
#   '선수',
#   '말',
#   '위',
#   '에서',
#   '저리',
#   '울다',
#   '사람',
#   '보다',
#   '적',
#   '없다',
#   '낙마',
#   '해도',
#   '침착하다',
#   '말',
#   '리더',
#   '로',
#   '다사',
#   '완주',
#   '우리',
#   '나라',
#   '선수',
#   '같이',
#   '대응',
#   '게',
#   '맞다',
#   '낙마',
#   '안',
#   '말다',
#   '듣다',
#   '저리',
#   '울다',
#   '선수',
#   '첨',
#   '보다',
#   '말',
#   '리더',
#   '필요하다',
#   '리더',
#   '멘탈',
#   '붕괴',
#   '인데',
#   '어찌',
#   '장애물',
#   '을',
#   '넘다',
#   '말',
#   '리더',
#   '없다',
#   '무섭다'],
#  ['훈련',
#   '부족하다',
#   '말',
#   '뿐',
#   '인데',
#   '무슨',
#   '교감',
#   '승',
#   '마을',
#   '한다는',
#   '건',
#   '지',
#   '종목',
#   '접다',
#   '우리',
#   '전통',
#   '줄',
#   '타다',
#   '종목',
#   '넣다'],
#  ['게',
#   '공',
#   '정성',
#   '있다',
#   '수',
#   '있다',
#   '틀',
#   '딱',
#   '뭐',
#   '문제',
#   '인지',
#   '못',
#   '느끼다',
#   '보다'],
#  ['도대체',
#   '이렇다',
#   '올림픽',
#   '종목',
#   '누가',
#   '보다',
#   '이건',
#   '수정',
#   '필요하다',
#   '보이지',
#   '않다',
#   '선수',
#   '수년',
#   '간',
#   '노력',
#   '그날',
#   '무작위',
#   '말',
#   '컨디션',
#   '따르다',
#   '물',
#   '거품',
#   '되다',
#   '말',
#   '안되다',
#   '똥통',
#   '같다',
#   '전통',
#   '을',
#   '고수',
#   '말고',
#   '시대',
#   '맞다',
#   '공',
#   '정성',
#   '을',
#   '담보',
#   '게',
#   '뭐',
#   '여'],
#  ['승마', '빼', '라', '제발', '제발', '말', '이랑', '선수', '두다', '불쌍하다', '제발', '빼다', '시발'],
#  ['내', '다', '짠하다', 'ㅠ'],
#  ['동물',
#   '진짜',
#   '변수',
#   '많다',
#   '오랫동안',
#   '준비',
#   '선수',
#   '맘',
#   '느껴지다',
#   '맴',
#   '않다',
#   '좋다',
#   '그래도',
#   '수고'],
#  ['나중',
#   '저기',
#   '영상',
#   '나오다',
#   '코치',
#   '경기',
#   '끝나다',
#   '나오다',
#   '말',
#   '에게',
#   '죽통',
#   '날림',
#   'ㅋㅋㅋ',
#   '그걸',
#   '보다',
#   '올림픽',
#   '관계자',
#   '신',
#   '고함',
#   'ㅋㅋㅋ'],
#  ['이렇다', '규칙', '을', '스포츠', '넣다', '대가리', '니까', '올림픽', '따다', '전통', '졸라', '좋아하다'],
#  ['오다', '진짜', '오', '바다', 'ㅠㅠㅠㅠㅠㅠㅠ', '얼마나', '서럽다', 'ㅠㅠㅠㅠㅠㅠㅠ'],
#  ['말', '대한', '배려', '없다', '일본'],
#  ['승마',
#   '문제',
#   '많다',
#   '이건',
#   '아니다',
#   '본인',
#   '실력',
#   '과는',
#   '무관',
#   '근',
#   '대',
#   '오',
#   '종',
#   '승마',
#   '이건',
#   '실력',
#   '아니다',
#   '운',
#   'ㅉㅉ'],
#  ['가챠', '게임', '똥', '종목', '저', '말', '잡다', '깔끔하다', '구', '먹다', '시', '마이'],
#  ['말',
#   '안',
#   '들다',
#   '뒈지다',
#   '같다',
#   '느낌',
#   '을',
#   '주다',
#   '그렇다',
#   '패왕색',
#   '있다',
#   '닝겐',
#   '되다',
#   '같다',
#   'ㅋㅋㅋ'],
#  ['이렇다', '실력', '범주', '들어가다', '올림픽', '종목', '에서', '빼다'],
#  ['말', '일본', '특유색깔', '모형', '싫다', '아니다', '생각', '드네', '요'],
#  ['게', '올림픽', '정신', '이냐'],
#  ['말', '너무', '불쌍하다'],
#  ['씨발',
#   '장애물',
#   '옆',
#   '끔찍하다',
#   '장식',
#   '놓다',
#   '것',
#   '보다',
#   '말',
#   '예민하다',
#   '귀',
#   '까지',
#   '덮다',
#   '경기',
#   '저',
#   '거',
#   '보고',
#   '안',
#   '놀라다',
#   '말',
#   '런던',
#   '올림픽',
#   '때',
#   '별반',
#   '다르다',
#   '않다'],
#  ['승마', '빼다'],
#  ['이렇다',
#   '경기',
#   '너무',
#   '야만',
#   '적',
#   '이고',
#   '비',
#   '인간',
#   '적',
#   '인',
#   '경기',
#   '인',
#   '것',
#   '같다',
#   '무슨',
#   '스포츠',
#   '인지',
#   '모르다',
#   '그냥',
#   '동물학대',
#   '아니다'],
#  ['나',
#   '같다',
#   '경기',
#   '끝나다',
#   '빚',
#   '을',
#   '내다',
#   '저',
#   '말',
#   '산다',
#   '음',
#   '데려가다',
#   '목',
#   '따다',
#   '말고기',
#   '로',
#   '팔',
#   '아버',
#   '린다'],
#  ['결국', '말', '성격', '빨', '크다'],
#  ['시대', '바뀌다', '차라리', '적의', '오토바이', '나', '자동차', '탈취', '라는', '컨셉', '변경', '되어다'],
#  ['그건', '아니다', '키', '좌'],
#  ['선수', '안쓰럽다', '말', '안쓰럽다', '움', 'ㅠ', '동물', '제발', '인간', '일', '에서', '빼다'],
#  ['저런', '걸', '왜', '올림픽', '넣다', '운빨', '변수', '너무', '크다', '같다'],
#  ['차라리', '대회', '몇', '일전', '말', '지급', '적응', '기간', '이라도', '갖다', '저', '게뭐', '야'],
#  ['저기',
#   '나가다',
#   '말',
#   '기본',
#   '적',
#   '비월',
#   '을',
#   '훈련',
#   '받다',
#   '말',
#   '들이다',
#   '대충',
#   '아무',
#   '말',
#   '이나',
#   '던지다',
#   '놓다',
#   '아니다',
#   '또한',
#   '앞',
#   '에서',
#   '실격',
#   '만들다',
#   '말',
#   '을',
#   '자다',
#   '억',
#   '누르다',
#   '달래다',
#   '정상',
#   '적',
#   '달리다',
#   '경우',
#   '있다',
#   '변수',
#   '많다',
#   '종목',
#   '이기다',
#   '하지만',
#   '그렇다고',
#   '단순',
#   '운',
#   '으로만',
#   '진행',
#   '되다',
#   '경기도',
#   '아니다',
#   '그리고',
#   '저기',
#   '참가',
#   '선수',
#   '그렇다',
#   '변수',
#   '이해',
#   '하고',
#   '통제',
#   '수',
#   '있다',
#   '판단',
#   '하고',
#   '참가'],
#  ['너글', '이다', '딧노'],
#  ['여기',
#   '쿨',
#   '찌다',
#   '들이다',
#   '있다',
#   '논리',
#   '적',
#   '인',
#   '전개',
#   '없이',
#   '비아',
#   '냥',
#   '대다',
#   '쿨하다',
#   '척',
#   '말다',
#   '제',
#   '댓글',
#   '을',
#   '읽다',
#   '다음',
#   '논리',
#   '적',
#   '인',
#   '답변',
#   '부탁드리다'],
#  ['백몽', '팩트', '체크', '안', '하고', '그냥', '올라오다', '사다', '알', '고', '깔다', '대중', '많다'],
#  ['히',
#   '히',
#   '서운하다',
#   '댓글',
#   '보다',
#   '승마',
#   '에서',
#   '점',
#   '더',
#   '나아가다',
#   '실격',
#   '을',
#   '안당',
#   '사람',
#   '운',
#   '좋다',
#   '그렇다',
#   '퉁',
#   '치다',
#   '버리다',
#   '댓글',
#   '많이',
#   '있다',
#   '놀라다'],
#  ['ㄹㅇ', '감정', '호소', '영상', 'ㅈ', '같다'],
#  ['웃기다', '새끼', '얼마나', '지다', '안되다', '그르', '냐'],
#  ['이건', '미치다', '종목', '이다', '인간', '미치다', '짖다', '언제', '쯤', '멈추다'],
#  ['저', '선수', '안타깝다', '말', '불쌍하다'],
#  ['저런', '승마', '그냥', '주', '겨', '야', '되다'],
#  ['안타깝다'],
#  ['보기',
#   '만해',
#   '답답하다',
#   '안타깝다',
#   '말',
#   '정말',
#   '형평성',
#   '있다',
#   '배정',
#   '되다',
#   '말',
#   '수준',
#   '모두',
#   '평준화',
#   '되어다',
#   '있다',
#   '동물',
#   '이기',
#   '때문',
#   '같다',
#   '조건',
#   '테스트',
#   '통과',
#   '해도',
#   '변수',
#   '있다',
#   '그',
#   '이전',
#   '부터',
#   '까다롭다',
#   '배정',
#   '돼다',
#   '듯',
#   '그리고',
#   '말',
#   '을',
#   '짧다',
#   '시간',
#   '안',
#   '다루다',
#   '기술',
#   '도구',
#   '배제',
#   '되어다',
#   '문제',
#   '다른',
#   '개선',
#   '점',
#   '을',
#   '찾다',
#   '것',
#   '같다',
#   '진짜',
#   '적의',
#   '말',
#   '을',
#   '빼앗다',
#   '탈때',
#   '갖은',
#   '방법',
#   '을',
#   '다',
#   '써다',
#   '타다'],
#  ['운빨', '로', '올림픽', '치다', '말', '이나', '되다', '소리', '냐'],
#  ['선민사상',
#   'ㅈㄴ',
#   '역겹다',
#   '올림픽',
#   '동네',
#   '체욱',
#   '대회',
#   '인',
#   '줄',
#   '아',
#   '나',
#   'ㅋㅋㅋ',
#   '선수',
#   '안타깝다',
#   '어쩔',
#   '수',
#   '없다'],
#  ['근데', '저건', '말', '잘못', '아니다'],
#  ['황우진',
#   '선수',
#   '보',
#   '니까',
#   '심지어',
#   '서로',
#   '에게',
#   '위험',
#   '까지',
#   '해보다',
#   '취지',
#   '존중',
#   '다지',
#   '만',
#   '운',
#   '좋다',
#   '선',
#   '안되다',
#   '보다'],
#  ['아니다'],
#  ['미개하다', '양', '놈', '스포츠', '죠', '쯧'],
#  ['동감', '이다'],
#  ['말',
#   '바꾸다',
#   '기회',
#   '주다',
#   '공정하다',
#   '제비',
#   '뽑기',
#   '냐',
#   '뭐',
#   '같다',
#   '규칙',
#   '이네',
#   'ㅡㅡ'],
#  ['이건', '사람', '올림픽', '아니다', '동물', '올림픽', '이네', '요'],
#  ['모든',
#   '말',
#   '어지간하다',
#   '스트레스',
#   '받다',
#   '어쩌면',
#   '그',
#   '때문',
#   '선수',
#   '낙마',
#   '크게',
#   '다치다',
#   '수도',
#   '있다',
#   '이건',
#   '대책',
#   '반드시',
#   '필요하다'],
#  ['저', '말', '말', '육회', '되다'],
#  ['방사', '능', '말', '같다'],
#  ['저',
#   '같이',
#   '말타',
#   '입장',
#   '에서',
#   '너무나',
#   '공감',
#   '되다',
#   '부분',
#   '많다',
#   '비슷하다',
#   '경험',
#   '있다',
#   '선수',
#   '마음',
#   '을',
#   '충분하다',
#   '이해',
#   '있다',
#   'ㅜ'],
#  ['속', '상', 'ㅠㅠㅠ'],
#  ['운', '실력', '이다', '껄껄', '껄', '폭탄', '돌리다', '가즈', '아'],
#  ['뜬금',
#   '없다',
#   '소리',
#   '지만',
#   '세기',
#   '이렇다',
#   '종목',
#   '왜',
#   '있다',
#   '장대높이뛰기',
#   '투포환',
#   '투창',
#   '승마',
#   '팬싱',
#   '등등',
#   '구시대',
#   '유물',
#   '같다',
#   '없애다',
#   '안되다'],
#  ['싫다',
#   '말',
#   '에게도',
#   '잔인하다',
#   '수',
#   '년',
#   '간',
#   '노력',
#   '을',
#   '운',
#   '배정',
#   '받다',
#   '선수',
#   '에게도',
#   '잔인하다',
#   '룰'],
#  ['종합',
#   '게임',
#   '챼널',
#   '사람',
#   '전기충격기',
#   '로',
#   '지지다',
#   '사이코패스',
#   '같다',
#   '사람',
#   '지다',
#   '들다',
#   '고기',
#   '먹다',
#   '착하다',
#   '척',
#   '비꼬다',
#   '쓸다',
#   '같다',
#   '댓글',
#   '반응',
#   '그래서',
#   '비건',
#   '하',
#   '라는',
#   '거임',
#   'ㅋㅋㅋㅋ',
#   '재밌다'],
#  ['성이름', '일단', '니', '뇌', '에다', '전기', '충격', '가하다', '필요', '있다', '듯', 'ㅋㅋ'],
#  ['다이아몬드', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['댓글', '문재인', '지지자', '비슷하다', '성향', '을', '가지다', '사람', '보이다'],
#  ['콜',
#   '필드',
#   '근데',
#   '나다',
#   '그',
#   '논리',
#   '로',
#   '항상',
#   '얘기',
#   '해오다',
#   '찾아보다',
#   '육식',
#   '얻다',
#   '모든',
#   '영양분',
#   '다',
#   '채식',
#   '으로도',
#   '얻다',
#   '수',
#   '있다',
#   '들이다',
#   '우리',
#   '살다',
#   '시대',
#   '식물성',
#   '지방',
#   '식물성',
#   '단백질',
#   '등',
#   '채식',
#   '만으로',
#   '인간',
#   '에게',
#   '필요하다',
#   '모든',
#   '영양분',
#   '을',
#   '얻다',
#   '수',
#   '있다',
#   '시대',
#   '인게',
#   '팩트',
#   '임'],
#  ['애초',
#   '노력',
#   '만큼',
#   '보상',
#   '받다',
#   '스포츠',
#   '취지',
#   '아니다',
#   '그냥',
#   '처음',
#   '부터',
#   '종목',
#   '룰',
#   '그렇다',
#   '운빨',
#   '개입',
#   '되다',
#   '모든',
#   '스포츠',
#   '공통',
#   '사항',
#   '임',
#   '우리',
#   '아무리',
#   '열심히',
#   '연습',
#   '우사인볼트',
#   '보다',
#   '빨리',
#   '달리다',
#   '수',
#   '있다',
#   '동양인',
#   '태어나다',
#   '순간',
#   '금메달',
#   '노력',
#   '여',
#   '하와',
#   '관계없이',
#   '평생',
#   '딸',
#   '수가',
#   '없다',
#   '그래서',
#   '인종',
#   '별로',
#   '메달',
#   '주',
#   '자고',
#   '룰',
#   '개정',
#   '말',
#   '고르다',
#   '담',
#   '대회',
#   '에서',
#   '운빨',
#   '로',
#   '좋다',
#   '말',
#   '얻다',
#   '있다',
#   '인종',
#   '바꾸다',
#   '못',
#   '것',
#   '스포츠',
#   '일부',
#   '인거',
#   '임'],
#  ['안타깝다',
#   '처음',
#   '운전면허',
#   '시험',
#   '장',
#   '에서',
#   '점수',
#   '채점',
#   '제대로',
#   '안되다',
#   '똥차',
#   '받다',
#   '억울하다',
#   '기억',
#   '나다'],
#  ['적의',
#   '말',
#   '을',
#   '빼앗다',
#   '타다',
#   '설정',
#   '알다',
#   '적어도',
#   '말',
#   '훈련',
#   '시키다',
#   '되다',
#   '아니다',
#   '일부러',
#   '선수',
#   '애',
#   '먹이다',
#   '뭐',
#   '야'],
#  ['내',
#   '저',
#   '상황',
#   '이다',
#   '미치다',
#   '돌아서다',
#   '그냥',
#   '말',
#   '에서',
#   '내리다',
#   '내',
#   '장애물',
#   '넘다',
#   '달리다',
#   '눈물',
#   '질질',
#   '짜다'],
#  ['선수', '블랙', '카드', '로', '쫒다', '겨', '난', '선', '순', '가요'],
#  ['ㅋㅋㅋ',
#   '지다',
#   '말',
#   '하고',
#   '친해지다',
#   '않다',
#   '지질',
#   '짜다',
#   'ㅋㅋㅋ',
#   '선수',
#   '아니다',
#   '새끼',
#   'ㅋㅋㅋ'],
#  ['선수', '불쌍하다', '이유', '없이', '태우다', '야하다', '말', '불쌍하다', '승마', '없애다', '라그', '냥'],
#  ['왜',
#   '전장',
#   '이라',
#   '적군',
#   '말',
#   '빼다',
#   '설정',
#   '이면',
#   '메달',
#   '빼다',
#   '그렇다',
#   '헝거게임',
#   '하',
#   '라',
#   '그렇다',
#   '시',
#   '대',
#   '착오',
#   '적',
#   '인거',
#   '랑',
#   '전통',
#   '적',
#   '인거',
#   '랑',
#   '구분',
#   '을',
#   '못',
#   '올림픽',
#   '위원회',
#   '수준'],
#  ['말',
#   '불쌍하다',
#   '이렇다',
#   '경기',
#   '왜',
#   '있다',
#   '건지다',
#   '경기',
#   '끝나다',
#   '주먹',
#   '때리다',
#   '동물학대',
#   '논란',
#   '때문',
#   '저',
#   '선수',
#   '출전',
#   '정지',
#   '돼다',
#   '여기',
#   '서다',
#   '여론',
#   '좋다'],
#  ['말', '안', '되다', '소리'],
#  ['말', '칼', '로', '찌르다', '죽이다', '무죄', '지'],
#  ['애',
#   '당초',
#   '말',
#   '정말',
#   '예민하다',
#   '동물',
#   '인데',
#   '안',
#   '그렇다',
#   '의도',
#   '대로',
#   '자다',
#   '안',
#   '움직이다',
#   '놈',
#   '을',
#   '시작',
#   '주먹',
#   '팼으',
#   '니',
#   '퍽',
#   '이나',
#   '자다',
#   '달다',
#   '저',
#   '선수',
#   '코치',
#   '못',
#   '만나다',
#   '경기',
#   '망치다',
#   '임'],
#  ['종합',
#   '게임',
#   '챼널',
#   '그래서',
#   '안',
#   '그렇다',
#   '의도',
#   '대로',
#   '자다',
#   '안',
#   '움직이다',
#   '이라고',
#   '써다',
#   '글',
#   '이나',
#   '똑바로',
#   '읽다',
#   '답글',
#   '달다',
#   '허다',
#   '접다'],
#  ...]

# %% [markdown]
# ### 토크나이저 사용
# 토크나이저를 사용해서 빈도를 추출한다

# %%
# 토크나이저 사용해서 빈도순으로 단어집합 ㄱㄱ
# fit_on_texts는 입력한 텍스트로부터 단어 빈도수가 높은 순으로 낮은 정수 인덱스를 부여함

tokenizer = Tokenizer()
tokenizer.fit_on_texts(res)

# %%
# 당연하겠지만 말이 젤 많이 나왔네요
print(tokenizer.word_index)
# Out:
# {'말': 1, '을': 2, '선수': 3, '아니다': 4, '있다': 5, '저': 6, '같다': 7, '종목': 8, '되다': 9, '보다': 10, '경기': 11, '승마': 12, '올림픽': 13, '안': 14, '사람': 15, '로': 16, '너무': 17, '에서': 18, '없다': 19, '다': 20, '교감': 21, '안타깝다': 22, '진짜': 23, '게': 24, '동물': 25, '않다': 26, '것': 27, '고': 28, '이다': 29, '그렇다': 30, '거': 31, '못': 32, '운': 33, '스포츠': 34, 'ㅋㅋ': 35, '안되다': 36, '그냥': 37, '좋다': 38, '실력': 39, '왜': 40, '운빨': 41, '받다': 42, '네': 43, '맞다': 44, '뭐': 45, '타다': 46, '이네': 47, '인데': 48, '듣다': 49, '들다': 50, '말고기': 51, '때리다': 52, '내': 53, '불쌍하다': 54, '자다': 55, '만': 56, '생각': 57, '나': 58, 'ㅠㅠ': 59, '수': 60, '적': 61, '전쟁': 62, '하고': 63, '무슨': 64, '아': 65, '그': 66, '더': 67, '인': 68, '주다': 69, '바꾸다': 70, '인간': 71, '저런': 72, '이건': 73, '다른': 74, '알다': 75, '시간': 76, '자기': 77, '먹다': 78, '얼마나': 79, '요': 80, '이렇다': 81, '싶다': 82, 'ㅋㅋㅋ': 83, 'ㅋㅋㅋㅋ': 84, '빼다': 85, '울다': 86, '문제': 87, '노력': 88, '나오다': 89, '룰': 90, '속상하다': 91, '라': 92, '버리다': 93, '임': 94, '가다': 95, '장애물': 96, '오다': 97, '시키다': 98, '한테': 99, '모르다': 100, '만들다': 101, '지': 102, '스트레스': 103, '냐': 104, '때': 105, '나다': 106, '말다': 107, '때문': 108, '이랑': 109, '야': 110, '랜덤': 111, '야하다': 112, '면': 113, '아프다': 114, '복불복': 115, '말로': 116, '준비': 117, '치다': 118, '하': 119, '상황': 120, '코치': 121, '니': 122, '어떻다': 123, '뛰다': 124, '많다': 125, '채찍': 126, 'ㅠ': 127, '개': 128, '위험하다': 129, '서': 130, '뽑기': 131, 'ㅜㅜ': 132, '이라': 133, '게임': 134, '걸': 135, '이고': 136, '메달': 137, '분': 138, '정도': 139, '근데': 140, '뭔': 141, '저건': 142, '저러다': 143, '훈련': 144, '몇': 145, '없애다': 146, '이나': 147, '추첨': 148, '보이다': 149, '이지': 150, '정말': 151, '배정': 152, 'ㅈ': 153, '처음': 154, '일본': 155, '듯': 156, '싫다': 157, '지다': 158, '자체': 159, '까지': 160, '년': 161, '따다': 162, '능력': 163, '따르다': 164, '해주다': 165, '저렇게': 166, '하나': 167, '죽이다': 168, '중': 169, '마음': 170, '일': 171, '돼다': 172, '넘다': 173, '본인': 174, '에게': 175, '차다': 176, '기': 177, '경': 178, '아무리': 179, '처럼': 180, '대로': 181, '눈물': 182, '많이': 183, '전': 184, '쓰다': 185, '라고': 186, '넣다': 187, '중요하다': 188, '친해지다': 189, '랑': 190, '이해': 191, '뽑다': 192, '크다': 193, '컨디션': 194, '함': 195, '새끼': 196, '학대': 197, '같이': 198, '영상': 199, '규칙': 200, '이라고': 201, 'ㅋ': 202, '예민하다': 203, '건': 204, '니까': 205, '없어지다': 206, '부터': 207, '소리': 208, '김유신': 209, '시대': 210, '인가': 211, '잘못': 212, '동물학대': 213, '알': 214, '대회': 215, '되어다': 216, '바로': 217, '보고': 218, '힘들다': 219, '자신': 220, '마지막': 221, '댓글': 222, '위해': 223, '해보다': 224, '그리고': 225, '끝나다': 226, '걸리다': 227, '애초': 228, '수도': 229, '해': 230, '당하다': 231, '바뀌다': 232, '독일': 233, '필요하다': 234, '난': 235, '누가': 236, '너': 237, '울': 238, '내다': 239, '라는': 240, '이유': 241, '떨어지다': 242, '짜다': 243, '존나': 244, '추다': 245, '모든': 246, '이제': 247, '이상하다': 248, '정신': 249, '퇴': 250, '열심히': 251, '애': 252, '건가': 253, '다르다': 254, '연습': 255, '입장': 256, '이야': 257, '패': 258, '죽다': 259, '놈': 260, '공정하다': 261, '죄': 262, '슬프다': 263, '낙마': 264, '맘': 265, '망겜': 266, 'ㅡㅡ': 267, '목': 268, '질': 269, '고르다': 270, 'ㅋㅋㅋㅋㅋ': 271, 'ㅜ': 272, '과의': 273, '이라는': 274, '태우다': 275, '위': 276, '휴': 277, '안좋다': 278, '이승엽': 279, '시': 280, '규정': 281, '부분': 282, '대': 283, '이냐': 284, '타고': 285, '해도': 286, '표정': 287, '주먹': 288, '분만': 289, '거부': 290, '기분': 291, '인지': 292, '점': 293, '놓다': 294, '달리다': 295, '기수': 296, '보': 297, '이라도': 298, '한다는': 299, '이런': 300, '경기장': 301, '터': 302, '정유': 303, '뺏다': 304, '날': 305, '폐지': 306, '등': 307, '이딴': 308, '미치다': 309, '대체': 310, '금메달': 311, '통제': 312, '수준': 313, '엄청': 314, '간': 315, '지금': 316, '결과': 317, '짧다': 318, '그렇게': 319, 'ㅈㄴ': 320, '그래서': 321, '제': 322, '솔직하다': 323, '그게': 324, '당연하다': 325, '다루다': 326, '데': 327, '억울하다': 328, '죠': 329, '나라': 330, '말타': 331, '만나다': 332, '모습': 333, '그래도': 334, '갑자기': 335, '방식': 336, '이용': 337, '차라리': 338, '달다': 339, '인생': 340, '또': 341, '늘다': 342, '개인': 343, '이르다': 344, '이렇게': 345, '심하다': 346, '나가다': 347, '일이': 348, '어쩔': 349, '완전': 350, '죽': 351, '아무': 352, '끝': 353, '이라니': 354, '님': 355, '분전': 356, '변수': 357, '상태': 358, '출전': 359, '우리나라': 360, '안쓰럽다': 361, 'ㄹㅇ': 362, '컨트롤': 363, '느끼다': 364, '취지': 365, '고생': 366, '여': 367, '방사': 368, '맞추다': 369, '선택': 370, '충분하다': 37 ...

# %%
# 말이 몇번 나왔는지 한번 보겠습니다
print(tokenizer.word_counts['말'])
# Out:
# 5112

# %%
# 신조어로 보이는 운빨망겜 얼마나 나왔는지 한번 보겠습니당
print(tokenizer.word_counts['운빨망겜'])
# Out:
# 5

# %% [markdown]
# 일단은 신조어를 뽑는다는 생각 말고 단순히 불용어 제거, 토큰화하고 빈도 추출하는 부분만 고려했습니다.
#
# 확인해 보니까 불용어에 기본적인 단어들이 너무 상위빈도를 차지해서, 기본 단어 모두 제거한 후에 빈도수를 추출해야 신조어를 추출할 수 있지 않을까 싶기도 합니다. ㅜ
